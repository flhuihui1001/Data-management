# %% [markdown]
# ### Project 3 - due Friday, 12/9 at 12pm
#
# Work in groups of four people per project.
#
# Select a dataset of at least 250,000 records, preferably at the level of individual transactions. Acquire the data, survey it, wrangle it into a suitable format, and analyze it. Present your work in a brief (8-10 minute) talk in class on Tuesday, 12/6, and write up your process and results in a reproducible notebook.
#
# You may use any of the methods we studied in class: Unix command line tools, relational databases and dimensional models with SQLite or PostgreSQL, or Spark. The datanotebook.org server will remain available until the end of the semester and may be used for the project.
#
# Attestation: All project team members should contribute meaningfully to the final results. Please attest to your individual contributions and that each member contributed substantially to the project in your final writeup.
#
# Deadline: Friday, 12/9, 12pm. Submit your presentation (PDF export), your notebook, and any additionally necessary files like scripts or images together in one zip file. Only one team member should submit on behalf of all members. All team members should post their projects to GitHub for reviews after the deadline has passed.

# %% [markdown]
# ### Part 1 - Selection (30 points)
#
# Identify and describe your dataset, its source, and what appeals to you about it. Acquire the data and perform an initial exploration to determine which themes you wish to explore. Describe the questions you want to be able to answer with the data, any concerns you have about the data, and any challenges you expect to have to overcome.

# %% [markdown]
# ### Data Source:
#  This time we choose 2016 Property Assessment data of Los Angeles, which dataset is available at the following website:
# https://data.lacounty.gov/Parcel-/Assessor-Parcels-Data-2016/7rjj-f2pv.
# We choose this website is because it is LAcounty government website, which means the data is very persuasive, accurate, comprehensive and powerful.
#
# ### The reason that we choose this dataset:
# ·   	Culture reason:
# We all love California and we think CA is a really nice place to live, also LA is known as “city of angels” which is a really charming and beautiful city. Because of these fact, we are interested in and want to get some acknowledge about the valuation and property of LA county.
#
# ·      About data itself:
# The data set that we choose contain a lot of values (columns) and very comprehensive and useful information that help us get better knowledge of LA property, also with future analysis. Our original data have 51 columns, about 4,800,000 rows, which also means the data (records) is very persuasive and comprehensive. Here we list the description of each column that we are interested in:
#
#   1: ZIPcode: Zip code in suits address, 9 digits or 5 digits
#
#   2: TaxRateArea_CITY: Incorporated city name based on tax rate area
#
#   3: AIN: Unique 10-digit number assigned to each parcel in LA county
#
#   4: TaxRateArea: Area code that corresponding to TaxRateArea_City
#
#   5: PropertyType: Type of property based on what the property used for
#
#   6: PropertyUseCode: Code for describing the overall use of the property
#
#   7: GeneralUseType: General use type of the property(residential/commercial/irrigated farm. etc.)
#
#   8: SpecificUseType: More specific use type of the property.(Camp/Bank/Cemetery. etc.)
#
#   9: SpecificUseDetail1: Additional property usage detail(Auto Service/Beverage/Car Wash. etc.)
#
#  10: SpecificUseDetail2: Additional property usage detail(Fast Food/Five Stories/Convenience Store. etc.)
#
#  11: YearBuilt: original year of property that built in
#
#  12: EffectiveYearBuilt: Effective year that property had construction, re 	modeling building maintenance, etc.
#
#  13: SQFTmain: total square feet of the structure(s)
#
#  14: Bedrooms: number of bedrooms that each structure has
#
#  15: Bathrooms: number of bathrooms that each structure has
#
#  16: Units: number of living units that each structure has
#
#  17: RecordingYear: last recording year for the property
#
#  18: RecordingMonth: last recording month for the property
#
#  19: LandValue: Land value on the assessment roll
#
#  20: LandBaseYear: Year of owner registered for the land
#
#  21: ImprovementValue: Improvement value on the assessment roll
#
#  22: ImpBaseYear: Year of owner registered for the improvement
#
#  23: TotalLandImpValue: Sum of the land value and improvement value
#
#  24: FixtureExemption: Fixture exemption value on the assessment roll
#
#  25: TotalExemption: Total exemption value for each owner on the property
#
#  26: netTaxableValue: Total value for the whole property (include land) for paying the tax
#
#  27: StreetName: The street name of the property located in
#
#  28: City: The city name of the property located in
#
#  29: ZIPcode5: The zip code of the area of property located in
#
#
#
#
# ### Initial exploration:
# We are interested in:
# ·      10 most popular cities people liked to live in
#
# ·      10 most expensive and cheap places for buying houses
#
# ·      -3 most common type of houses
#
# ·      -trend of numbers of properties that built in past several years
#
# ·       -what are the prices/values for same type of house in 10 years ago and nowadays(what are the main reason(s) cost this price change? Analyze from certain land value in different years, certain land improvement value in different years and change of exemption for people in certain time period)
#
# ### Concerns and challenges:
# ·      We have a very large size of data set(1.07G), which can not be uploaded directly to Trifecta(100M limited) to clean data and to Jupyter Notebook to clean data and analyze data. So we need to find a way to successfully upload and clean data set, and then analyze data.
#
#
# ·      Too many information, including duplicated information, we need to clearly understand each column’s meaning, organize data and draw the dimension tables and fact table, and delete some duplicated information.

# %% [markdown]
# ### Part 2 - Wrangling (35 points)
# Based on what you found above, wrangle the data into a format suitable for analysis. This may involve cleaning, filtering, merging, and modeling steps, any and all of which are valid for this project. Describe your process as you proceed, and document any scripts, databases, or other models you develop. Be specific about any key decisions to modify or remove data, how you overcame any challenges, and all assumptions you make about the meaning of variables and their values.Verify that your wrangling steps have succeeded (for example, if you loaded the data into a dimensional model, ensure that the fact table contains the right number of records).

# %% [markdown]
# #### Summary:
# As we mentioned in part 1, we have a large set of data, so we can not upload the data set once to the Trifacta, also because the large size data, it will take a very long time to run each step of analysis in part 3. So our group first divide the whole data set into 35 small data set, and we upload data set one by one into Trifacta and clean the data set, then we randomly choose 6 data sets from 35 sets and do the exploration and analysis.
#
# We use Trifacta to drop some columns that we are not interested or not relevant to our analysis, or some columns which have duplicated information.
# Delete unexpected sign, such as “%”,”$,”-“ etc. Below are the details that how we clean our data.

# %% [markdown]
# #### Trifacta steps and explanation details:
#
# #### We dropped the above columns from the data as they were not relevant to our analysis.
# drop col: RollYear, AssessorID, PropertyLocation, totBuildingDataLines, HomeownersExemption, RealEstateExemption, FixtureValue, PersonalPropertyValue, PersonalPropertyExemption, isTaxableParcel, TotalValue, SpecialParcelClassification, AdministrativeRegion, cluster, ParcelBoundaryDescription, HouseFraction, HouseNo, StreetDirection, UnitNo, rowID, CENTER_LON, CENTER_LAT, Location_1
# splitrows col: column1 on: '\r\n' quote: '\"'
# split col: column1 on: ',' limit: 28 quote: '\"'
# replace col: * with: '' on: '\"' global: true
# header
# drop col: ZIPcode
# drop col: SpecificUseDetail1
# drop col: FixtureExemption
# drop col: TotalExemption
# drop col: netTaxableValue
# drop col: StreetName
# drop col: ZIPcode5
#
#
# ### We extracted the month and year from the recordingdate column and then split them so they could be analyzed separately, then renamed them to avoid confusion.
# replace col: RecordingDate with: '' on: `{digit}{2}{end}`
#
# extract col: RecordingDate on: `{digit}{2}` after: `{digit}{4}` before: `{end}`
#
# replace col: RecordingDate with: '' on: `{digit}{2}{end}`
#
# rename col: RecordingDate1 to: 'RecordingMonth'
#
# rename col: RecordingDate to: 'RecordingYear'
#
#
#
# ### Changed landvalue column to remove unneeded characters and to make the column into floats for easier analysis.
# replace col: LandValue with: '' on: `"` global: true
#
# replace col: LandValue with: '' on: `$` global: true
#
# replace col: LandValue with: '' on: `,` global: true
#
#
# ### Changed improvementvalue column to remove unneeded characters and to make the column into floats for easier analysis.
# replace col: ImprovementValue with: '' on: `$` global: true
#
# replace col: ImprovementValue with: '' on: `"` global: true
#
# replace col: ImprovementValue with: '' on: `,` global: true
#
# ### Changed totallandimpvalue column to remove unneeded characters and to make the column into floats for easier analysis.
# replace col: TotalLandImpValue with: '' on: `"` global: true
#
# replace col: TotalLandImpValue with: '' on: `$` global: true
#
# replace col: TotalLandImpValue with: '' on: `,` global: true
#
#
# ### Changed fixtureexemption column to remove unneeded characters and to make the column into floats for easier analysis.
# replace col: FixtureExemption with: '' on: `$` global: true
#
# replace col: FixtureExemption with: '' on: ',' global: true
#
#
# ### Changed nettaxablevalue column to remove unneeded characters and to make the column into floats for easier analysis.
# replace col: netTaxableValue with: '' on: `$` global: true
#
# replace col: netTaxableValue with: '' on: `"` global: true
#
# replace col: netTaxableValue with: '' on: `,` global: true
#
#
# ### Changed totalexemption column to remove unneeded characters and to make the column into floats for easier analysis.
# replace col: TotalExemption with: '' on: '\"' global: true
#
# replace col: TotalExemption with: '' on: `$` global: true
#
# replace col: TotalExemption with: '' on: ',' global: true
#
#
# ### deleted mismatched zipcode so that we do not have any entries with incorrectly entered or formatted zip codes.
# delete row: mismatched(ZIPcode, ['Zipcode'])
#
# ### deleted rows without zip codes as we will be analyzing based on zip code.
# delete row: empty([ZIPcode])
#
# ### deleted rows without zip codes(zipcode5 represents zip code after removing the ‘-‘ and the numbers following that) because we expect to need it for analysis.
# delete row: empty([ZIPcode5])

# %% [markdown]
# First, let's read and import the file, we zip the 6 csv files together and unzip it in jupyter notebook by using "!unzip".

# %%
# !wget https://github.com/gwsb-istm-6212-fall-2016/Sifan-Du-istm-6212/raw/master/cleaned.zip
# Out:
# --2016-12-09 16:49:55--  https://github.com/gwsb-istm-6212-fall-2016/Sifan-Du-istm-6212/raw/master/cleaned.zip
# Resolving github.com (github.com)... 192.30.253.112, 192.30.253.113
# Connecting to github.com (github.com)|192.30.253.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/Sifan-Du-istm-6212/master/cleaned.zip [following]
# --2016-12-09 16:49:56--  https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/Sifan-Du-istm-6212/master/cleaned.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.32.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10192382 (9.7M) [application/octet-stream]
# Saving to: ‘cleaned.zip’
#
# cleaned.zip         100%[=====================>]   9.72M  --.-KB/s   in 0.1s
#
# ...

# %%
# !unzip cleaned.zip
# Out:
# Archive:  cleaned.zip
#    creating: cleaned/
#   inflating: cleaned/1.csv
#   inflating: cleaned/2.csv
#   inflating: cleaned/3.csv
#   inflating: cleaned/4.csv
#   inflating: cleaned/5.csv
#   inflating: cleaned/6.csv

# %% [markdown]
# Here we use "csvstack" to merge 6 different csv files vertically (by same column names). Then we check how many rows the file has and list the column names of our data set. We can see we can 380192 rows totally and 22 variables(columns).

# %%
# !csvstack cleaned/1.csv cleaned/2.csv cleaned/3.csv cleaned/4.csv cleaned/5.csv cleaned/6.csv  > ladata.csv

# %%
# !wc -l ladata.csv
# Out:
# 380192 ladata.csv

# %%
# !csvcut -n ladata.csv
# Out:
#   1: TaxRateArea_CITY
#   2: AIN
#   3: TaxRateArea
#   4: PropertyType
#   5: PropertyUseCode
#   6: GeneralUseType
#   7: SpecificUseType
#   8: SpecificUseDetail2
#   9: YearBuilt
#  10: EffectiveYearBuilt
#  11: SQFTmain
#  12: Bedrooms
#  13: Bathrooms
#  14: Units
#  15: RecordingYear
#  16: RecordingMonth
#  17: LandValue
#  18: LandBaseYear
#  19: ImprovementValue
#  20: ImpBaseYear
#  21: TotalLandImpValue
#  22: City

# %% [markdown]
# !csvstat la.csv

# %% [markdown]
# ### Null Value
#
# #5. PropertyType
# #9. SpecificUseDetail1
# #10. SpecificUseDetail2

# %% [markdown]
# Since the total data that we have right now is still kind of big, so we just run one of the file and we can see that PropertyType, SpecificUseDetail1 and SpecificUseDetail2 have Null Value.

# %%
# %load_ext sql
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# !echo 'redspot' | sudo -S service postgresql restart
# Out:
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.

# %%
# !dropdb -U dbuser --if-exists final
# Out:
# NOTICE:  database "final" does not exist, skipping

# %%
# !createdb -U dbuser final

# %%
# %sql postgresql://dbuser@localhost:5432/final
# Out:
# 'Connected: dbuser@final'

# %% [markdown]
# ### Create table and import

# %% [markdown]
# Here, we create a table named ladata, with the variables that we are interested in, which contain all the columns that we are interested in.

# %%
# %%sql
#     DROP TABLE IF EXISTS ladata;
#     CREATE TABLE ladata (
#     TaxRateArea_CITY VARCHAR(500),
#     AIN CHAR(1000),
#     TaxRateArea VARCHAR(500),
#     PropertyType VARCHAR(1000),
#     PropertyUseCode VARCHAR(1000),
#     GeneralUseType VARCHAR(1000),
#     SpecificUseType VARCHAR(1000),
#     SpecificUseDetail2 VARCHAR(1000),
#     YearBuilt INTEGER,
#     EffectiveYearBuilt INTEGER,
#     SQFTmain INTEGER,
#     Bedrooms INTEGER,
#     Bathrooms INTEGER,
#     Units INTEGER,
#     RecordingYear INTEGER,
#     RecordingMonth CHAR(1000),
#     LandValue DECIMAL,
#     LandBaseYear INTEGER,
#     ImprovementValue DECIMAL,
#     ImpBaseYear INTEGER,
#     TotalLandImpValue DECIMAL,
#     City VARCHAR(500)
# );
# Out:
# Done.
# Done.
# []

# %%
# !pwd
# Out:
# /home/jovyan/work

# %%
# %%sql
# COPY ladata FROM '/home/jovyan/work/ladata.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 380191 rows affected.
# []

# %%
# %%sql
#
# SELECT COUNT(*) FROM ladata;
# Out:
# 1 rows affected.
# [(380191,)]

# %% [markdown]
# Above, we run a COUNT(*) query to verify that all the data has loaded correctly, as we can see, both output shows 380191 rows at this moment from our data set.
#
# Below, we are going to check Null value again.

# %%
# %%sql
# UPDATE ladata SET TaxRateArea_CITY = 'Null' where TaxRateArea_CITY is null;
# UPDATE ladata SET AIN = 'Null' where AIN is null;
# UPDATE ladata SET TaxRateArea = 'Null' where TaxRateArea is null;
# UPDATE ladata SET PropertyType = 'Null' where PropertyType is null;
# UPDATE ladata SET PropertyUseCode = 'Null' where PropertyUseCode is null;
# UPDATE ladata SET GeneralUseType = 'Null' where GeneralUseType is null;
# UPDATE ladata SET SpecificUseType = 'Null' where SpecificUseType is null;
# UPDATE ladata SET SpecificUseDetail2 = 'Null' where SpecificUseDetail2 is null;
# UPDATE ladata SET YearBuilt = -999 where YearBuilt is null;
# UPDATE ladata SET EffectiveYearBuilt = -999 where EffectiveYearBuilt is null;
# UPDATE ladata SET SQFTmain = -999 where SQFTmain is null;
# UPDATE ladata SET Bedrooms = -999 where Bedrooms is null;
# UPDATE ladata SET Bathrooms = -999 where Bathrooms is null;
# UPDATE ladata SET Units = -999 where Units is null;
# UPDATE ladata SET RecordingYear = -999 where RecordingYear is null;
# UPDATE ladata SET RecordingMonth = 'Null' where RecordingMonth is null;
# UPDATE ladata SET LandValue = -999 where LandValue is null;
# UPDATE ladata SET LandBaseYear = -999 where LandBaseYear is null;
# UPDATE ladata SET ImprovementValue = -999 where ImprovementValue is null;
# UPDATE ladata SET ImpBaseYear = -999 where ImpBaseYear is null;
# UPDATE ladata SET TotalLandImpValue = -999 where TotalLandImpValue is null;
# UPDATE ladata SET City = 'Null' where City is null;
# Out:
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# []

# %% [markdown]
# ### Star Schema

# %% [markdown]
# ### Part 3 - Analysis (35 points)
#
# Explore and analyze your data in its wrangled form. Follow through on the themes you identified in Part 1 with queries or scripts that answer the questions you had in mind. Be clear about the answers you discover, discussing them and whether the results match your expectations. Include charts or other visuals that support your analysis. You may use Tableau, ggplot, or other tools we have not covered in class for visualization, but be sure to export images and to include them properly in your writeup.

# %% [markdown]
# Before analysis, let's check our table and variables type again.

# %%
# %%sql
#
# SELECT COUNT(*) FROM ladata;
# Out:
# 1 rows affected.
# [(380191,)]

# %%
# %%sql
#
# SELECT column_name,data_type
# FROM INFORMATION_SCHEMA.COLUMNS WHERE table_name='ladata';
# Out:
# 22 rows affected.
# [('taxratearea_city', 'character varying'),
#  ('ain', 'character'),
#  ('taxratearea', 'character varying'),
#  ('propertytype', 'character varying'),
#  ('propertyusecode', 'character varying'),
#  ('generalusetype', 'character varying'),
#  ('specificusetype', 'character varying'),
#  ('specificusedetail2', 'character varying'),
#  ('yearbuilt', 'integer'),
#  ('effectiveyearbuilt', 'integer'),
#  ('sqftmain', 'integer'),
#  ('bedrooms', 'integer'),
#  ('bathrooms', 'integer'),
#  ('units', 'integer'),
#  ('recordingyear', 'integer'),
#  ('recordingmonth', 'character'),
#  ('landvalue', 'numeric'),
#  ('landbaseyear', 'integer'),
#  ('improvementvalue', 'numeric'),
#  ('impbaseyear', 'integer'),
#  ('totallandimpvalue', 'numeric'),
#  ('city', 'character varying')]

# %% [markdown]
# The following query list top 6 propertytype that happened most in LA county, as we can see in order, there are Single Family Residence, Condominum, Residential-income, Vacant, and other. As what we expected, Single Family Residence is the majority propertytype.

# %%
# %%sql
#
#
# SELECT PropertyType, COUNT(AIN) AS "Number of Properties"
# FROM ladata
# GROUP BY PropertyType
# ORDER BY "Number of Properties" desc
# Limit 6;
# Out:
# 6 rows affected.
# [('SFR', 271820),
#  ('CND', 44332),
#  ('R-I', 39326),
#  ('C/I', 18362),
#  ('VAC', 3377),
#  ('OTH', 2964)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# ([<matplotlib.patches.Wedge at 0x7f93fc0e29b0>,
# ...
#   <matplotlib.text.Text at 0x7f93fc107f28>])

# %% [markdown]
# ### Top 5 popular cities
# Here we are interest in finding out the 5 most popular cities(the cities has number of properties most). Los Angeles is the top popular city which as 107164 properties, which has almost has twice much properties as the second city, Long Beach. This is in our expection, since the area of Los Angeles is the largest city compared with other cities. Combine with the histogram, we can easily tell that Los Angeles, Long Beach and Santa Clarita are the top 3 cities that people like to live in. We are going to use these top 3 cities do the further analysis and create a general proposal for people who want to do investment of property in LA.

# %%
# %%sql
#
#
# SELECT TaxRateArea_CITY, COUNT(AIN) AS "Number of Properties"
# FROM ladata
# GROUP BY TaxRateArea_CITY
# ORDER BY COUNT(AIN) DESC
# LIMIT 5;
# Out:
# 5 rows affected.
# [('LOS ANGELES', 107164),
#  ('LONG BEACH ', 67891),
#  ('SANTA CLARITA', 50861),
#  ('unincorporated', 23762),
#  ('POMONA     ', 23487)]

# %% [markdown]
# TaxRateArea_CITY
# LOS ANGELES
# LONG BEACH
# SANTA CLARITA

# %%
result = _
result.bar(color='red')
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ### Find out the most expensive city in LA!
# There, we calculate the top 5 expensive cities based on the average landvalue, and we can see that Malibu is the most expensive landvalue city that has average landvalue is about 2204333. Suprisely, Los Angeles, Long Beach and Santa Clarita are not in this list.

# %%
# %%sql
# SELECT TaxRateArea_CITY, AVG(LandValue) as aveLandValue
# FROM ladata
# GROUP BY TaxRateArea_CITY
# ORDER BY aveLandValue DESC
# limit 5;
# Out:
# 5 rows affected.
# [('MALIBU', Decimal('2204333.155717761557')),
#  ('LAKEWOOD', Decimal('728641.520782396088')),
#  ('BURBANK', Decimal('661630.903945111492')),
#  ('CLAREMONT', Decimal('590464.074074074074')),
#  ('PARAMOUNT', Decimal('548301.300000000000'))]

# %%
result = _
result.bar(color='yellow')
# Out:
# <Container object of 5 artists>

# %% [markdown]
# There, we calculate the top 5 expensive cities based on the average imporvementvalue, and we can see that Glendora is the most expensive improvment value city that has average improvementvalue is about 749057, however, the difference improvement value among top 4 cities is not very big. Again, Los Angeles, Long Beach and Santa Clarita are not in this list.

# %%
# %%sql
# SELECT TaxRateArea_CITY,AVG(ImprovementValue) as aveImpValue
# FROM ladata
# GROUP BY TaxRateArea_CITY
# ORDER BY aveImpValue DESC
# limit 5;
# Out:
# 5 rows affected.
# [('GLENDORA   ', Decimal('749057.111111111111')),
#  ('CLAREMONT', Decimal('742368.750000000000')),
#  ('MALIBU', Decimal('703288.317518248175')),
#  ('LAKEWOOD', Decimal('698643.100244498778')),
#  ('PARAMOUNT', Decimal('605839.400000000000'))]

# %%
result = _
result.bar(color='blue')
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ### The most expensive city in LA: Malibu!
# Here is the rank of 5 expensive cities based on average value of total land and improvement value, as we can see, the top 3 cities are Malibu, Lakewood and Claremont, based on last two queries, we can make a general conclusion that Malibu are the city has top one land value, number 3 improvment value and the city which has most expensive improvement and land value(about 2907621). Based on these, we believe that Malibu city is the place that the richest people in LA like to live in.

# %%
# %%sql
# SELECT TaxRateArea_CITY,AVG(TotalLandImpValue) as aveTotalValue
# FROM ladata
# GROUP BY TaxRateArea_CITY
# ORDER BY aveTotalValue DESC
# limit 5;
# Out:
# 5 rows affected.
# [('MALIBU', Decimal('2907621.473236009732')),
#  ('LAKEWOOD', Decimal('1427284.621026894866')),
#  ('CLAREMONT', Decimal('1332832.824074074074')),
#  ('GLENDORA   ', Decimal('1256794.777777777778')),
#  ('BURBANK', Decimal('1224866.801029159520'))]

# %%
result = _
result.bar(color='green')
# Out:
# <Container object of 5 artists>

# %% [markdown]
# ### Analysis and general proposal for the 3 most popular cities in LA:
# After analyze which city is where the most rich people live in(has most expensive land value, improvement value and total value in general. As we mentioned before, we are going to analyzed deeperly about the 3 most popular cities(have the highest number of properties): LOS ANGELES, LONG BEACH, SANTA CLARITA. Later, based on our analysis, we are going to make a gereral proposal for people who want to do property investment in these three cities in LA.

# %% [markdown]
# Frist analysis part, lets compare the values among these three cities.
#
# Lets start with calculate the average land value in LOS ANGELES, LONG BEACH, SANTA CLARITA respectively. As we can see, Los Angeles has thehighest average land value among these 3 cities, with average land value:283260, follwing with Long beach 253060 and Santa Clarita 190654.

# %%
# %%sql
# SELECT TaxRateArea_CITY,AVG(LandValue) as aveLandValue
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES' or TaxRateArea_CITY ='LONG BEACH ' or TaxRateArea_CITY ='SANTA CLARITA'
# GROUP BY TaxRateArea_CITY
# Out:
# 3 rows affected.
# [('LONG BEACH ', Decimal('253060.838918266044')),
#  ('LOS ANGELES', Decimal('283260.525316337576')),
#  ('SANTA CLARITA', Decimal('190654.648768211400'))]

# %%
result = _
result.bar(color='purple')
# Out:
# <Container object of 3 artists>

# %% [markdown]
# ### Average Improvement Value in Los Angeles, Long beach, and Santa Clarita
#
# Then, we calculate the average improvement value in these 3 cities. This time, Santa Clarita has the highest average land value among these 3 cities! with average improvement value:265102, followed by Los Angeles 243444 and Long Beach 179994. Which we think is because the cost of  construction is more expensive in Santa Clarita, or is rich people who like to built luxury buildings prefer to stay in Santa Clarity than Los Angeles and Long Beach.

# %%
# %%sql
# SELECT TaxRateArea_CITY,AVG(ImprovementValue) as aveImpValue
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES' or TaxRateArea_CITY ='LONG BEACH ' or TaxRateArea_CITY ='SANTA CLARITA'
# GROUP BY TaxRateArea_CITY
# Out:
# 3 rows affected.
# [('LONG BEACH ', Decimal('179994.489785096699')),
#  ('LOS ANGELES', Decimal('243444.492460154530')),
#  ('SANTA CLARITA', Decimal('265102.656298539156'))]

# %%
result = _
result.bar(color='purple')
# Out:
# <Container object of 3 artists>

# %% [markdown]
# ### Average Improvement + LandPrice Value in Los Angeles, Long beach, and Santa Clarita
#
# Here we calculate the average total land and improvement value in these 3 cities. Not surprise, LOS ANGELES has the highest average total value among these 3 cities, since we believe Los Angeles is still the biggest area and is the most popular one! Which with average improvement value:526705, followed by SANTA CLARITA 455757 and Long Beach 433055.

# %%
# %%sql
# SELECT TaxRateArea_CITY,AVG(TotalLandImpValue) as aveTotalValue
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES' or TaxRateArea_CITY ='LONG BEACH ' or TaxRateArea_CITY ='SANTA CLARITA'
# GROUP BY TaxRateArea_CITY
# Out:
# 3 rows affected.
# [('LONG BEACH ', Decimal('433055.328703362743')),
#  ('LOS ANGELES', Decimal('526705.017776492106')),
#  ('SANTA CLARITA', Decimal('455757.305066750555'))]

# %%
result = _
result.bar(color='purple')
# Out:
# <Container object of 3 artists>

# %% [markdown]
# #### Second analysis part:
#
# We are focused on the proportion of the general use type in each these three cities. First, lets see the how general use type proportion looks like in the whole LA county. As we can see more than 90% of the use type is residential.

# %%
# %%sql
# SELECT GeneralUseType, COUNT(GeneralUseType) as count
# FROM ladata
# GROUP BY GeneralUseType
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [('Residential', 357905),
#  ('Commercial', 13751),
#  ('Industrial', 5254),
#  ('Institutional', 1664),
#  ('Miscellaneous', 1292)]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='generalusetype', y='count', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# #### Second analysis part:
#
# We are focused on the proportion of the general use type in each these three cities. First, lets see the how general use type proportion looks like in the whole LA county. As we can see more than 90% of the use type is residential.

# %%
# %%sql
# SELECT GeneralUseType, COUNT(GeneralUseType) as count
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES'
# GROUP BY GeneralUseType
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [('Residential', 99216),
#  ('Commercial', 4807),
#  ('Industrial', 1736),
#  ('Institutional', 711),
#  ('Miscellaneous', 591)]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='generalusetype', y='count', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# ### LONG BEACH's general use type
# Here we count the general use type in Long Beach, we can see majority use type is Residential, which actually is 96%, proportion of Commerical is 3% and industrial proportion is 1% after we calculated by excel.

# %%
# %%sql
# SELECT GeneralUseType, COUNT(GeneralUseType) as count
# FROM ladata
# WHERE TaxRateArea_CITY ='LONG BEACH '
# GROUP BY GeneralUseType
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [('Residential', 64834),
#  ('Commercial', 2328),
#  ('Industrial', 372),
#  ('Institutional', 246),
#  ('Miscellaneous', 66)]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='generalusetype', y='count', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# #### Santa Clarita's general use type
#
# Here we count the general use type in Santa Clarita, we can see majority use type is Residential, which actually is 97%, proportion of Commerical is 2% and industrial proportion is 1% after we calculated by excel.

# %%
# %%sql
# SELECT GeneralUseType, COUNT(GeneralUseType) as count
# FROM ladata
# WHERE TaxRateArea_CITY ='SANTA CLARITA'
# GROUP BY GeneralUseType
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [('Residential', 49586),
#  ('Commercial', 820),
#  ('Industrial', 302),
#  ('Institutional', 88),
#  ('Miscellaneous', 30)]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='generalusetype', y='count', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# #### Conclusion:
# After Analysis, we found that in LOS ANGELES, LONG BEACH, SANTA CLARITA, most of the properties are Residential,and Los Angeles has more proportion of other property use types (4% commercial and 2% industrial) compared with other 2 cities. SANTA CLARITA has the highest proportion of residentical, which means most people in SANTA CLARITA is to stay and live there.
#
# Now we are interested in whether there are more Commercial or Industrial properties in L.A city. As we can see from the following two charts, about 50% of the Commerical properties located in L.A city, about 25% of commerical properties located in Long Beach city, about 15% located in Burbank.
#
# About 50% of Industrial in L.A county located in L.A city, long beach, burbank, Sinal Hill and Pomona has about the same percentage of industrial. This shows that most industrial and commercial properties located in L.A city. is the largest and best place to investment has, because L.A has more opportunities and places than others.

# %%
# %%sql
# SELECT TaxRateArea_CITY, COUNT(GeneralUseType) as count
# FROM ladata
# WHERE GeneralUseType = 'Commercial'
# GROUP BY TaxRateArea_CITY
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [('LOS ANGELES', 4807),
#  ('LONG BEACH ', 2328),
#  ('BURBANK    ', 1361),
#  ('POMONA     ', 851),
#  ('SANTA CLARITA', 820)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ef741f98>,
# ...
#   <matplotlib.text.Text at 0x7f93f16409b0>])

# %%
# %%sql
# SELECT TaxRateArea_CITY, COUNT(GeneralUseType) as count
# FROM ladata
# WHERE GeneralUseType = 'Industrial'
# GROUP BY TaxRateArea_CITY
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [('LOS ANGELES', 1736),
#  ('POMONA     ', 554),
#  ('BURBANK    ', 481),
#  ('SIGNAL HILL', 418),
#  ('LONG BEACH ', 372)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93f15cf6a0>,
# ...
#   <matplotlib.text.Text at 0x7f93f15e0f60>])

# %% [markdown]
# #### Analysis part 3:
# Now we are going to count and analyze the total number of some most common type of house in L.A county, here we take  1b1b(1 bed 1 bath),2b2b,3b2b as example, and find value each of the house type in each of the three cities in both 2000 and 2010, and analyze how the price change after 10 years later.
#
# Conclusion: Long Beach has most 1b1b, which means most family has small number of people live in Long Beach, and  average total value for 1b1b in L.A city from 2000 to 2010 increased about 148%(165320/111406), average total value for 1b1b in long beach city from 2000 to 2010 increase about 138% (187387/136271), average total value for 1b1b in Santa CLARITA from 2000 to 2010 increase about 133% (151451/114052). So the value for 1b1b increase faster in L.A city than in long beach and Santa CLARITA.

# %% [markdown]
# ### 1b1b: top 10 in LA

# %%
# %%%sql
# SELECT TaxRateArea_CITY, COUNT(AIN) AS "NumberofProperties"
# FROM ladata
# WHERE Bathrooms = '1' and Bedrooms = '1'
# GROUP BY TaxRateArea_CITY
# ORDER BY "NumberofProperties" DESC
# limit 10
# Out:
# 10 rows affected.
# [('LONG BEACH ', 2232),
#  ('LOS ANGELES', 1467),
#  ('SANTA CLARITA', 1036),
#  ('POMONA     ', 366),
#  ('unincorporated', 355),
#  ('BURBANK    ', 235),
#  ('SIGNAL HILL', 146),
#  ('LAKEWOOD   ', 127),
#  ('PARAMOUNT  ', 111),
#  ('CERRITOS   ', 94)]

# %%
result = _
result.bar(color='purple')
# Out:
# <Container object of 10 artists>

# %% [markdown]
# ### LOS ANGELES 1b1b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '1' and Bedrooms = '1' and TaxRateArea_CITY ='LOS ANGELES' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2010, Decimal('165320.902777777778')),
#  (2000, Decimal('111406.240000000000'))]

# %%
result = _
result.bar(color='purple')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# ### LONG BEACH 1b1b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '1' and Bedrooms = '1' and TaxRateArea_CITY ='LONG BEACH ' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2010, Decimal('187387.435483870968')),
#  (2000, Decimal('136271.333333333333'))]

# %%
result = _
result.bar(color='purple')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# ### SANTA CLARITA 1b1b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '1' and Bedrooms = '1' and TaxRateArea_CITY ='SANTA CLARITA' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2000, Decimal('114052.904109589041')),
#  (2010, Decimal('151451.377777777778'))]

# %%
result = _
result.bar(color='purple')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# #### The following steps help us analyze the 2b2b situation:
#
#
# After ran the queries, we make a conclusion that L.A city has most 2b2b, which means most small to median size family live in L.A city. Average total value for 2b2b in L.A city from 2000 to 2010 increased about 159%(313145/197467), average total value for 1b1b in long beach city from 2000 to 2010 increase about 138%(333535/242244), average total value for 2b2b in Santa CLARITA from 2000 to 2010 increase about 133% (151451/114052). So the value for 2b2b increase faster in L.A city than in long beach and Santa CLARITA.

# %% [markdown]
# ### 2b2b: top 10 in LA

# %%
# %%%sql
# SELECT TaxRateArea_CITY, COUNT(AIN) AS "NumberofProperties"
# FROM ladata
# WHERE Bathrooms = '2' and Bedrooms = '2'
# GROUP BY TaxRateArea_CITY
# ORDER BY "NumberofProperties" DESC
# limit 10
# Out:
# 10 rows affected.
# [('LOS ANGELES', 7158),
#  ('SANTA CLARITA', 7108),
#  ('LONG BEACH ', 5925),
#  ('BURBANK    ', 2349),
#  ('unincorporated', 2047),
#  ('POMONA     ', 1518),
#  ('SIGNAL HILL', 944),
#  ('LAKEWOOD   ', 858),
#  ('CLAREMONT  ', 491),
#  ('BELLFLOWER ', 467)]

# %%
result = _
result.bar(color='green')
# Out:
# <Container object of 10 artists>

# %% [markdown]
# ### LOS ANGELES 2b2b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '2' and Bedrooms = '2' and TaxRateArea_CITY ='LOS ANGELES' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2000, Decimal('197467.750000000000')),
#  (2010, Decimal('313145.629539951574'))]

# %%
result = _
result.bar(color='green')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# ### LONG BEACH 2b2b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '2' and Bedrooms = '2' and TaxRateArea_CITY ='LONG BEACH ' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2010, Decimal('333535.414383561644')),
#  (2000, Decimal('242244.051282051282'))]

# %%
result = _
result.bar(color='green')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# ### SANTA CLARITA 2b2b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '1' and Bedrooms = '1' and TaxRateArea_CITY ='SANTA CLARITA' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2000, Decimal('114052.904109589041')),
#  (2010, Decimal('151451.377777777778'))]

# %%
result = _
result.bar(color='green')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# The following steps help us analyze the 3b2b situation:
#
# After ran the queries, we make a conclusion that L.A city has most 3b2b, which means most median to large size family in L.A city. Average total value for 3b2b in L.A city from 2000 to 2010 increased about 149%(352421/235823), average total value for 3b2b in long beach city from 2000 to 2010 increase about 147%(360884/248492), average total value for 3b2b in Santa CLARITA from 2000 to 2010 increase about 128% (302922/236527). So the value for 3b2b increase faster in L.A city than in long beach and Santa CLARITA. To sum up, no matter what kind of resident house type, the house property value increased faster in L.A city than Long Beach and Santa Clarita.

# %% [markdown]
# ###  3b2b: top 10 in LA

# %%
# %%%sql
# SELECT TaxRateArea_CITY, COUNT(AIN) AS "NumberofProperties"
# FROM ladata
# WHERE Bathrooms = '2' and Bedrooms = '3'
# GROUP BY TaxRateArea_CITY
# ORDER BY "NumberofProperties" DESC
# limit 10
# Out:
# 10 rows affected.
# [('LOS ANGELES', 18846),
#  ('LONG BEACH ', 16376),
#  ('SANTA CLARITA', 10691),
#  ('LAKEWOOD   ', 7005),
#  ('POMONA     ', 6425),
#  ('BURBANK    ', 4504),
#  ('unincorporated', 4072),
#  ('CERRITOS   ', 3333),
#  ('COVINA     ', 2517),
#  ('CLAREMONT  ', 2140)]

# %%
result = _
result.bar(color='orange')
# Out:
# <Container object of 10 artists>

# %% [markdown]
# ### LOS ANGELES 3b2b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '2' and Bedrooms = '3' and TaxRateArea_CITY ='LOS ANGELES' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2000, Decimal('235823.294444444444')),
#  (2010, Decimal('352421.896895787140'))]

# %%
result = _
result.bar(color='orange')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# ### LONG BEACH 3b2b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '2' and Bedrooms = '3' and TaxRateArea_CITY ='LONG BEACH ' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2010, Decimal('360884.696153846154')),
#  (2000, Decimal('248492.910081743869'))]

# %%
result = _
result.bar(color='orange')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# ### SANTA CLARITA 3b2b: 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(TotalLandImpValue) as "aveTotal"
# FROM ladata
# WHERE Bathrooms = '2' and Bedrooms = '3' and TaxRateArea_CITY ='SANTA CLARITA' and (RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# Out:
# 2 rows affected.
# [(2010, Decimal('302922.342379958246')),
#  (2000, Decimal('236527.927884615385'))]

# %%
result = _
result.bar(color='orange')
# Out:
# <Container object of 2 artists>

# %% [markdown]
# ####  The following steps is going to show how the three cities land value were improve between each 10 years from 1980 to 2010.
#
# we can see that the land value in L.A city increased very fast from 1980 to 1990, and increased little smoothly from 1990 to 2000, and increased quickly again from 2000 to 2010. Land value from long beach did not have a huge change from 1980 to 1990, and had a slightly decrease from 1990 to 2000, but changed quickly from 2000 to 2010. The land value in Santa Clarita increased shaply from 1980 to 1990, and 2000 to 2010, changed slowly from 1990 to 2000. Which can tell us the real estate market had period slow grouth between 1990 to 2000.

# %% [markdown]
# ### Los Angeles's Land Value: 1980 vs 1990 vs 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(LandValue) as "aveLand"
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES' and  ( RecordingYear = '1980' or RecordingYear = '1990' or RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# ORDER BY RecordingYear
# Out:
# 4 rows affected.
# [(1980, Decimal('107949.931034482759')),
#  (1990, Decimal('187603.559284116331')),
#  (2000, Decimal('210579.595423563778')),
#  (2010, Decimal('285952.548938800742'))]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='recordingyear', y='aveLand', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# ### Long Beach's Land Value: 1980 vs 1990 vs 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(LandValue) as "aveLand"
# FROM ladata
# WHERE TaxRateArea_CITY ='LONG BEACH ' and  ( RecordingYear = '1980' or RecordingYear = '1990' or RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# ORDER BY RecordingYear
# Out:
# 4 rows affected.
# [(1980, Decimal('78570.153846153846')),
#  (1990, Decimal('161646.343949044586')),
#  (2000, Decimal('154545.998615916955')),
#  (2010, Decimal('264233.285895404120'))]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='recordingyear', y='aveLand', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# ### Santa Clarita's Land Value: 1980 vs 1990 vs 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(LandValue) as "aveLand"
# FROM ladata
# WHERE TaxRateArea_CITY ='SANTA CLARITA' and  ( RecordingYear = '1980' or RecordingYear = '1990' or RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# ORDER BY RecordingYear
# Out:
# 4 rows affected.
# [(1980, Decimal('72830.816901408451')),
#  (1990, Decimal('135429.482014388489')),
#  (2000, Decimal('135544.422911283376')),
#  (2010, Decimal('178293.591261739486'))]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='recordingyear', y='aveLand', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# ####  The following steps is going to show how the three cities improvement value were improve between each 10 years from 1980 to 2010.
#
# we can see that for all the three city, the improvement value had a slowly increase trend from 1980 to 2010, but not as fast as land value increased.

# %% [markdown]
# ### Los Angeles's Improvement Value: 1980 vs 1990 vs 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(ImprovementValue) as "aveImp"
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES' and  ( RecordingYear = '1980' or RecordingYear = '1990' or RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# ORDER BY RecordingYear
# Out:
# 4 rows affected.
# [(1980, Decimal('165078.973180076628')),
#  (1990, Decimal('199306.464205816555')),
#  (2000, Decimal('200432.069620253165')),
#  (2010, Decimal('262555.403667834329'))]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='recordingyear', y='aveImp', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# ### Long Beach's Improvement Value: 1980 vs 1990 vs 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(ImprovementValue) as "aveImp"
# FROM ladata
# WHERE TaxRateArea_CITY ='LONG BEACH ' and  ( RecordingYear = '1980' or RecordingYear = '1990' or RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# ORDER BY RecordingYear
# Out:
# 4 rows affected.
# [(1980, Decimal('85253.623931623932')),
#  (1990, Decimal('131681.730360934183')),
#  (2000, Decimal('132123.902422145329')),
#  (2010, Decimal('164784.317908082409'))]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='recordingyear', y='aveImp', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# ### Santa Clarita's Improvement Value: 1980 vs 1990 vs 2000 vs 2010

# %%
# %%%sql
# SELECT RecordingYear, AVG(ImprovementValue) as "aveImp"
# FROM ladata
# WHERE TaxRateArea_CITY ='SANTA CLARITA' and  ( RecordingYear = '1980' or RecordingYear = '1990' or RecordingYear = '2000' or RecordingYear = '2010')
# GROUP BY RecordingYear
# ORDER BY RecordingYear
# Out:
# 4 rows affected.
# [(1980, Decimal('170331.394366197183')),
#  (1990, Decimal('179713.061151079137')),
#  (2000, Decimal('233375.182601205857')),
#  (2010, Decimal('252687.938342180482'))]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='recordingyear', y='aveImp', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# ### SpecificUseType

# %% [markdown]
# Here, we list top 5 specificusetype that propoerties have most, and we can seee single family residentce takes majority of the specuficustetype.

# %%
# %%sql
# SELECT SpecificUseType, COUNT(SpecificUseType) as count
# FROM ladata
# GROUP BY SpecificUseType
# ORDER BY count DESC
# limit 5
# Out:
# 5 rows affected.
# [('Single Family Residence', 318315),
#  ('Double, Duplex, or Two Units', 18573),
#  ('Five or More Units or Apartments (Any Combination)', 9371),
#  ('Four Units  (Any Combination)', 6166),
#  ('Three Units (Any Combination)', 5204)]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='specificusetype', y='count', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %% [markdown]
# ### Los Angeles's specific use type

# %% [markdown]
# #### The following couple of  steps  shows the top 5 popular SpecificUseType in L.A city, and  shows how many 1B1B,2B2B,3B2B in L.A city  for specificuseType :single family residence and Double, Duplex or Two Units in L.A city.

# %%
# %%sql
# SELECT SpecificUseType, COUNT(SpecificUseType) as count
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES'
# GROUP BY SpecificUseType
# ORDER BY count DESC
# limit 5
# Out:
# 5 rows affected.
# [('Single Family Residence', 78206),
#  ('Double, Duplex, or Two Units', 9597),
#  ('Five or More Units or Apartments (Any Combination)', 5124),
#  ('Four Units  (Any Combination)', 3452),
#  ('Three Units (Any Combination)', 2749)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee514940>,
# ...
#   <matplotlib.text.Text at 0x7f93ee52b358>])

# %%
# %%%sql
# SELECT  Bedrooms, COUNT(AIN) AS "Number of Properties"
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES' and SpecificUseType = 'Single Family Residence' and ((Bathrooms = '1' and Bedrooms = '1') or (Bathrooms = '2' and Bedrooms = '2') or (Bathrooms = '2' and Bedrooms = '3'))
# GROUP BY Bedrooms
# ORDER BY "Number of Properties"
# Out:
# 3 rows affected.
# [(1, 1395), (2, 5659), (3, 17247)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee478fd0>,
# ...
#   <matplotlib.text.Text at 0x7f93ee48b128>])

# %%
# %%%sql
# SELECT  Bedrooms, COUNT(AIN) AS "Number of Properties"
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES' and SpecificUseType = 'Double, Duplex, or Two Units' and ((Bathrooms = '1' and Bedrooms = '1') or (Bathrooms = '2' and Bedrooms = '2') or (Bathrooms = '2' and Bedrooms = '3'))
# GROUP BY Bedrooms
# ORDER BY "Number of Properties"
# Out:
# 3 rows affected.
# [(1, 27), (2, 1421), (3, 1546)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee4590b8>,
# ...
#   <matplotlib.text.Text at 0x7f93ee4651d0>])

# %% [markdown]
# #### Conclusion:
#
# The step above shows us how many no matter the specificusetype is singel family residence or Double, Duplex ot two units, we can tell that most house in L.A city is 3b2b. which also means that the Family in L.A city are larege families or rich small size family prefer big house.

# %% [markdown]
# ### LONG BEACH's specific use type

# %% [markdown]
# #### The following couple of  steps  shows the top 5 popular SpecificUseType in Long Beach, and  shows how many 1B1B,2B2B,3B2B in L.A city  for specificuseType :single family residence and Double, Duplex or Two Units in Long Beach.

# %%
# %%sql
# SELECT SpecificUseType, COUNT(SpecificUseType) as count
# FROM ladata
# WHERE TaxRateArea_CITY ='LONG BEACH '
# GROUP BY SpecificUseType
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [('Single Family Residence', 56322),
#  ('Double, Duplex, or Two Units', 4688),
#  ('Five or More Units or Apartments (Any Combination)', 1641),
#  ('Four Units  (Any Combination)', 1215),
#  ('Three Units (Any Combination)', 953)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee3b1fd0>,
# ...
#   <matplotlib.text.Text at 0x7f93ee3ca9e8>])

# %%
# %%%sql
# SELECT  Bedrooms, COUNT(AIN) AS "Number of Properties"
# FROM ladata
# WHERE TaxRateArea_CITY ='LONG BEACH ' and SpecificUseType = 'Single Family Residence' and ((Bathrooms = '1' and Bedrooms = '1') or (Bathrooms = '2' and Bedrooms = '2') or (Bathrooms = '2' and Bedrooms = '3'))
# GROUP BY Bedrooms
# ORDER BY "Number of Properties"
# Out:
# 3 rows affected.
# [(1, 2193), (2, 5434), (3, 15729)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee393e10>,
# ...
#   <matplotlib.text.Text at 0x7f93ee3a0f28>])

# %%
# %%%sql
# SELECT  Bedrooms, COUNT(AIN) AS "Number of Properties"
# FROM ladata
# WHERE TaxRateArea_CITY ='LONG BEACH ' and SpecificUseType = 'Double, Duplex, or Two Units' and ((Bathrooms = '1' and Bedrooms = '1') or (Bathrooms = '2' and Bedrooms = '2') or (Bathrooms = '2' and Bedrooms = '3'))
# GROUP BY Bedrooms
# ORDER BY "Number of Properties"
# Out:
# 3 rows affected.
# [(1, 10), (2, 449), (3, 625)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee2f2c50>,
# ...
#   <matplotlib.text.Text at 0x7f93ee2ffd68>])

# %% [markdown]
# #### Conclusion:
#
# The step above shows us that single family resident and Double, Duplex, or Two Units are the top 2 SpecificUseType in Long beach.Also the result for the number of 1b1b,2b2b,3b2b under each 2 SpecificUseType is very similiar with L.A city,which we also can tell that most house in L.A city is 3b2b. which also means that the Family in L.A city are larege families or rich small size family prefer big house.

# %% [markdown]
# ### Santa Clarita's general use type

# %%
# %%sql
# SELECT SpecificUseType, COUNT(SpecificUseType) as count
# FROM ladata
# WHERE TaxRateArea_CITY ='SANTA CLARITA'
# GROUP BY SpecificUseType
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [('Single Family Residence', 49115),
#  ('Five or More Units or Apartments (Any Combination)', 206),
#  ('Store', 168),
#  ('Double, Duplex, or Two Units', 164),
#  ('Light Manufacturing', 142)]

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib import rc


d = _.DataFrame()
rc('figure', figsize=(20, 8))
splt = sns.barplot(x='specificusetype', y='count', data=d)
labels = [l for l in splt.get_xmajorticklabels()]
splt.set_xticklabels(labels, rotation=30)

# %%
# %%%sql
# SELECT  Bedrooms, COUNT(AIN) AS "Number of Properties"
# FROM ladata
# WHERE TaxRateArea_CITY ='SANTA CLARITA' and SpecificUseType = 'Single Family Residence' and ((Bathrooms = '1' and Bedrooms = '1') or (Bathrooms = '2' and Bedrooms = '2') or (Bathrooms = '2' and Bedrooms = '3'))
# GROUP BY Bedrooms
# ORDER BY "Number of Properties"
# Out:
# 3 rows affected.
# [(1, 1035), (2, 7075), (3, 10655)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee252780>,
# ...
#   <matplotlib.text.Text at 0x7f93ee25d898>])

# %%
# %%%sql
# SELECT  Bedrooms, COUNT(AIN) AS "Number of Properties"
# FROM ladata
# WHERE TaxRateArea_CITY ='SANTA CLARITA' and SpecificUseType = 'Double, Duplex, or Two Units' and ((Bathrooms = '1' and Bedrooms = '1') or (Bathrooms = '2' and Bedrooms = '2') or (Bathrooms = '2' and Bedrooms = '3'))
# GROUP BY Bedrooms
# ORDER BY "Number of Properties"
# Out:
# 2 rows affected.
# [(3, 22), (2, 29)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee226780>,
# ...
#   <matplotlib.text.Text at 0x7f93ee22fc18>])

# %% [markdown]
# #### Conclusion:
#
# Again, single family resident and Double, Duplex, or Two Units are the top 2 SpecificUseType in Santa Clarita. 3B2B is still the most common type for single family resident, however, the interesting part is, for Duplex, or Two Units , there is no 1B1B in Santa Clarita,  which means there is almost no small family live in Santa Clarita, most of people here are have big family or perfer bigger house.

# %% [markdown]
# ### Last part, we are going to show the proportion for each city's SpecificUseDetail2 variable.

# %%
# %%sql
# SELECT SpecificUseDetail2, COUNT(SpecificUseDetail2) as count
# FROM ladata
# GROUP BY SpecificUseDetail2
# ORDER BY count DESC
# limit 6;
# Out:
# 6 rows affected.
# [(' ', 237518),
#  ('Pool', 48770),
#  ('Condominium', 39126),
#  ('Planned Unit Development (PUD)', 21705),
#  ('One Story', 18209),
#  ('Condo Conversion', 4926)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee17da58>,
# ...
#   <matplotlib.text.Text at 0x7f93ee195fd0>])

# %% [markdown]
# #### Conclusion:
#
# After calculation, we can see that in L.A city, there are about 64% of the property does not have anything in specificusedetail2, there are about 13% property have pool and 11% has Planned Unit Development (PUD).

# %% [markdown]
# ### LONG BEACH's Specific use Detail

# %%
# %%sql
# SELECT SpecificUseDetail2, COUNT(SpecificUseDetail2) as count
# FROM ladata
# WHERE TaxRateArea_CITY ='LONG BEACH '
# GROUP BY SpecificUseDetail2
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [(' ', 50532),
#  ('Pool', 5593),
#  ('Condominium', 3935),
#  ('One Story', 2611),
#  ('Condo Conversion', 1942)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee16e208>,
# ...
#   <matplotlib.text.Text at 0x7f93ee0febe0>])

# %% [markdown]
# #### Conclusion:
#
# After calculation, we can see that in long beach, there are about 78% of the property does not have anything in specificusedetail2, there are about 9% property have pool and 6% has Planned Unit Development (PUD).

# %% [markdown]
# ### SANTA CLARITA's Specific use Detail

# %%
# %%sql
# SELECT SpecificUseDetail2, COUNT(SpecificUseDetail2) as count
# FROM ladata
# WHERE TaxRateArea_CITY ='SANTA CLARITA'
# GROUP BY SpecificUseDetail2
# ORDER BY count DESC
# limit 5;
# Out:
# 5 rows affected.
# [(' ', 20119),
#  ('Condominium', 11248),
#  ('Planned Unit Development (PUD)', 9338),
#  ('Pool', 7402),
#  ('One Story', 999)]

# %%
# %matplotlib inline
result=_
result.pie()
# Out:
# ([<matplotlib.patches.Wedge at 0x7f93ee0cdda0>,
# ...
#   <matplotlib.text.Text at 0x7f93ee0e67b8>])

# %% [markdown]
# #### Conclusion:
#
# After calculation, we can see that in long beach, there are about 41% of the property does not have anything in specificusedetail2, there are about 23% property have pool and 19% has Planned Unit Development (PUD).
#
# Compared among the three city, for "specificusedetail2", proportion for properties have empty specificusedetail2 for each city are :64% 78% ,41% in order(L.A CITY,LONG BEACH, SANTA CLARITA). Proportion for having pool:13%, 9% 23% , proportion for having PUD: 11%, 6%,19%. Which we can make conclusion that properties in Santa Clarita are more fancy than properties in L.A CITY and long beach, which also means the people who are in Santa Clarita are richer than other two cites, and Santa Clarita has more space to built pool, PUD. etc.

# %% [markdown]
# ### General Proposal

# %%
# !pwd
# Out:
# /home/jovyan/work

# %%
from IPython.display import Image
PATH = "/home/jovyan/work/"

# %%
Image(filename = PATH + "Screen.png", width=1000, height=1000)

# %% [markdown]
# #### General Proposal
# Proposal for people who want to do investment about property in L.A county:
# L.A city has highest average land value and total average and total land and improvement value. Total average value followed by Santa Clarita and Long Beach. Based on the proportion of property used type, we suggest that if for who want to find a place to live, S.C is a good choose, since average total value is not very high and 97% percent of the property are residential, and 23% of the property have pool and 19% have PUD, which all means S.C is really nice for living. For who want to do investment about land in L.A, we suggest that he buy land in Long Beach, since the change (increase) of land value in Long Beach in 40 years is the biggest(highest) one, which is 3.36 times than 40 years ago. For who want to do investment about house(improvement) in LA, we suggest to buy improvement in L.A city, since the same of property type (for example 1b1b,2b2b.etc), increased most in 10 years compared with other 2 cities.

# %% [markdown]
# ### Bonus - Augment (10 points)
#
# Sometimes the most value can be gained from one dataset when it is studied alongside data drawn from other sources. Identify at least one additional data source that can complement your analysis. Pull this additional data into your chosen environment and explore at least one more theme you are able to further analyze that depends upon a combination of data from both sources.

# %% [markdown]
# #### Data Source: https://data.lacity.org/A-Prosperous-City/Listing-of-Active-Businesses/6rrh-rzua
# #### Download link: http://www.census.gov/programs-surveys/acs/
# #### This is a file that includes a  list of businesses in LA.

# %% [markdown]
# ### Trifacta:
#
# ### We dropped the above columns from the data as they were not relevant to our analysis.
# split col: column1 on: ',' limit: 15 quote: '\"'
#
# header
#
# drop col: DBA_NAME,STREET_ADDRESS
#
# drop col: ZIP_CODE, LOCATION_DESCRIPTION, MAILING_ADDRESS, MAILING_CITY, MAILING_ZIP_CODE, NAICS, PRIMARY_NAICS_DESCRIPTION, COUNCIL_DISTRICT, LOCATION_START_DATE, LOCATION_END_DATE, LOCATION
#
# #### We have included the cleaned data in the link below.

# %%
# !wget https://github.com/gwsb-istm-6212-fall-2016/Sifan-Du-istm-6212/raw/master/bb.zip
# Out:
# --2016-12-09 16:51:31--  https://github.com/gwsb-istm-6212-fall-2016/Sifan-Du-istm-6212/raw/master/bb.zip
# Resolving github.com (github.com)... 192.30.253.113, 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/Sifan-Du-istm-6212/master/bb.zip [following]
# --2016-12-09 16:51:31--  https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/Sifan-Du-istm-6212/master/bb.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.32.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7455086 (7.1M) [application/octet-stream]
# Saving to: ‘bb.zip’
#
# bb.zip              100%[=====================>]   7.11M  --.-KB/s   in 0.1s
#
# ...

# %%
# !unzip bb.zip
# Out:
# Archive:  bb.zip
#    creating: bb/
#   inflating: bb/1.csv
#   inflating: bb/2.csv
#   inflating: bb/3.csv
#   inflating: bb/4.csv
#   inflating: bb/5.csv
#   inflating: bb/6.csv
#   inflating: bb/7.csv

# %%
# !csvstack bb/1.csv bb/2.csv bb/3.csv bb/4.csv bb/5.csv bb/6.csv > bb.csv

# %%
# !wc -l bb.csv
# Out:
# 357276 bb.csv

# %%
# !csvcut -n bb.csv
# Out:
#   1: LOCATION_ACCOUNT
#   2: BUSINESS_NAME
#   3: CITY

# %%
# !csvstat bb.csv

# %%
# %%sql
#     DROP TABLE IF EXISTS bb;
#     CREATE TABLE bb (
#     LOCATION_ACCOUNT VARCHAR(20),
#     BUSINESS_NAME VARCHAR(100),
#     CITY VARCHAR(50)
# );
# Out:
# Done.
# Done.
# []

# %%
# !pwd
# Out:
# /home/jovyan/work

# %%
# %%sql
# COPY bb FROM '/home/jovyan/work/bb.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 357275 rows affected.
# []

# %%
# %%sql
#
# SELECT COUNT(*) FROM bb;
# Out:
# 1 rows affected.
# [(357275,)]

# %% [markdown]
# #### Below is the list of areas within LA county, listed by number of businesses. We can see that the city of Los Angeles has by far the most.

# %%
# %%sql
# SELECT CITY, COUNT (LOCATION_ACCOUNT) as count
# FROM bb
# GROUP BY CITY
# ORDER BY count DESC
# limit 10
# Out:
# 10 rows affected.
# [('LOS ANGELES', 181962),
#  ('VAN NUYS', 12942),
#  ('SHERMAN OAKS', 10007),
#  ('NORTH HOLLYWOOD', 8403),
#  ('WOODLAND HILLS', 7883),
#  ('ENCINO', 7359),
#  ('NORTHRIDGE', 6210),
#  ('STUDIO CITY', 5014),
#  ('CANOGA PARK', 4484),
#  ('TARZANA', 4208)]

# %% [markdown]
# #### Because our analysis on land value focused on Los Angeles, Long Beach, and Santa Clarita, we are interested in whether there would be similar patterns in the business data.

# %%
# %%sql
# SELECT CITY, COUNT (LOCATION_ACCOUNT) as count
# FROM bb
# WHERE CITY = 'LOS ANGELES'
# GROUP BY CITY
# Out:
# 1 rows affected.
# [('LOS ANGELES', 181962)]

# %%
# %%sql
# SELECT CITY, COUNT (LOCATION_ACCOUNT) as count
# FROM bb
# WHERE CITY = 'LONG BEACH'
# GROUP BY CITY
# Out:
# 1 rows affected.
# [('LONG BEACH', 943)]

# %%
# %%sql
# SELECT CITY, COUNT (LOCATION_ACCOUNT) as count
# FROM bb
# WHERE CITY = 'SANTA CLARITA'
# GROUP BY CITY
# Out:
# 1 rows affected.
# [('SANTA CLARITA', 418)]

# %%
# %%sql
# SELECT TaxRateArea_CITY,AVG(LandValue) as aveLandValue
# FROM ladata
# WHERE TaxRateArea_CITY ='LOS ANGELES' or TaxRateArea_CITY ='LONG BEACH ' or TaxRateArea_CITY ='SANTA CLARITA'
# GROUP BY TaxRateArea_CITY
# Out:
# 3 rows affected.
# [('LONG BEACH ', Decimal('253060.838918266044')),
#  ('LOS ANGELES', Decimal('283260.525316337576')),
#  ('SANTA CLARITA', Decimal('190654.648768211400'))]

# %% [markdown]
# #### From the business activity described in dataset bb, we can compare it to the average land values we queried previously. There appears to be a pattern where land value is positively correlated with number of buisnesses, though the relationship does not appear very strong.
