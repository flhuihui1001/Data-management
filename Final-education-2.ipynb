# %% [markdown]
# ### Data source:
#
# The data is from US department of education, you can download the data here: https://ed-public-download.apps.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip.
#
# For detailed explaination of each column, you can see the database documentation: https://collegescorecard.ed.gov/assets/FullDataDocumentation.pdf

# %%
# !wget https://ed-public-download.apps.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
# Out:
# --2016-12-03 22:19:19--  https://ed-public-download.apps.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
# Resolving ed-public-download.apps.cloud.gov (ed-public-download.apps.cloud.gov)... 107.23.95.12, 52.73.98.33, 2406:da00:ff00::3449:6221, ...
# Connecting to ed-public-download.apps.cloud.gov (ed-public-download.apps.cloud.gov)|107.23.95.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240264190 (229M) [application/zip]
# Saving to: ‘CollegeScorecard_Raw_Data.zip’
#
# CollegeScorecard_Ra 100%[=====================>] 229.13M  68.5MB/s   in 3.4s
#
# 2016-12-03 22:19:23 (67.4 MB/s) - ‘CollegeScorecard_Raw_Data.zip’ saved [240264190/240264190]

# %%
# !unzip CollegeScorecard_Raw_Data.zip
# Out:
# Archive:  CollegeScorecard_Raw_Data.zip
#   inflating: Crosswalks_20160908.zip
#   inflating: MERGED1996_97_PP.csv
#   inflating: MERGED1997_98_PP.csv
#   inflating: MERGED1998_99_PP.csv
#   inflating: MERGED1999_00_PP.csv
#   inflating: MERGED2000_01_PP.csv
#   inflating: MERGED2001_02_PP.csv
#   inflating: MERGED2002_03_PP.csv
#   inflating: MERGED2003_04_PP.csv
#   inflating: MERGED2004_05_PP.csv
#   inflating: MERGED2005_06_PP.csv
#   inflating: MERGED2006_07_PP.csv
#   inflating: MERGED2007_08_PP.csv
#   inflating: MERGED2008_09_PP.csv
#   inflating: MERGED2009_10_PP.csv
#   inflating: MERGED2010_11_PP.csv
#   inflating: MERGED2011_12_PP.csv
#   inflating: MERGED2012_13_PP.csv
#   inflating: MERGED2013_14_PP.csv
#   inflating: MERGED2014_15_PP.csv

# %%
# !csvstack -g 2006,2007,2008,2009,2010 MERGED2006_07_PP.csv MERGED2007_08_PP.csv MERGED2008_09_PP.csv MERGED2009_10_PP.csv  MERGED2009_10_PP.csv > Education.csv

# %%
# !wc -l Education.csv
# Out:
# 35012 Education.csv

# %%
# !sed s/NULL/data_na/ Education.csv > Education_refined.csv

# %% [markdown]
# ### Choose useful columns to create new datasets

# %% [markdown]
# I choose 25 columns that correlated with 7 aspects (listed in the order as the database)
#
# ### Basic information about Institutions
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#
# ### Award of the institution
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#
#     There are several elements that identify the degree profile of the institution. Highest degree (HIGHDEG) identifies the highest award level. This designation differs from the highest degree element in that it is based on an institution’s reported offerings, rather than on degree or certificate completions. For example, an institution may offer a bachelor’s degree program but only infrequently have students that earn the degree. The level of institution element would consistently classify this institution as 4-year, but the highest degree element would potentially vary from year-to-year.
#
# ### Administration rate
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#
#     For institutions with multiple branches, ADM_RATE includes the admissions rate at each campus, while ADM_RATE_ALL represents the admissions rate across all campuses, defined as the total number of admitted undergraduates across all branches divided by the total number of undergraduates who applied across all branches.
#
# ### SAT scores
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#
# ### Retention rate
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#
#     Available through the IPEDS Fall Enrollment component, retention rate identifies (separately) the share of full-time and part-time students in the prior year, at four-year (RET_FT4 and RET_PT4) and less-than-four- year institutions (RET_FTL4 and RET_PTL4), who return to the institution after the first year.
#
# ### Family income
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#
#     Using data from NSLDS, these elements calculate the percentage of Title IV-receiving students who had family income data from the Free Application for Federal Student Aid (FAFSA) for each of five income quintiles16 (INC_PCT_LO = $0-$30,000; INC_PCT_M1 = $30,001-$48,000; INC_PCT_M2=$48,001-$75,000; INC_PCT_H1=$75,001-$110,000; and INC_PCT_H2 = $110,001+).
#
# ### Debt of students
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18)
#
#     This is the median loan debt accumulatedat the institution by all student borrowers of federal loans who separate (i.e., either graduate or withdraw) in a given fiscal year, measured at the point of separation (DEBT_MDN).More specifically, the measure represents the sum of all undergraduate federal loans over students’ college education at the institution for which the median debt is reported for —e.g., if a student receives a federal loan for $2,000 for each of eight semesters at one institution,their cumulative debt is recorded as $16,000 forthat institution.
#     These data are available for all borrowers at the institution, as well as disaggregated by completion status (GRAD_DEBT_MDN for students who completed and WDRAW_DEBT_MDN for students who withdrew without completing25); by FAFSA family income26 (LO_INC_DEBT_MDN = $0-$30,000; MD_INC_DEBT_MDN = $30,001-$75,000; and HI_INC_DEBT_MDN = $75,001+);
#
# ### Earnings
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#
#     Mean (MN_EARN_WNE_P*) and median (MD_EARN_WNE_P*) earnings are for the institutional aggregate of all federally aided students who enroll in an institution each year and who are employed but not enrolled. Earnings are defined as the sum of wages and deferred compensation from all non-duplicate W-2 forms received for each individual, plus positive self- employment earnings from Schedule SE. Data are available for each year starting six years after a student enrolls in college, up to 10 years after the student enrolls; enrollment dates are estimated based on FAFSA self-reporting, as with the completion rate cohort construction described above.
#
#     Mean earnings are also available disaggregated by FAFSA family income31 (MN_EARN_WNE_INC1_P*, MN_EARN_WNE_INC2_P*, and MN_EARN_WNE_INC3_P*); by dependent status (for dependents, MN_EARN_WNE_INDEP0 _P*; and for independents, MN_EARN_WNE_INDEP1_P*); and by gender (for female, MN_EARN_WNE_MALE0_P*; and for male, MN_EARN_WNE_MALE1_P*).

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2014_15_PP.csv > education15.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2013_14_PP.csv > education14.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2012_13_PP.csv > education13.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2011_12_PP.csv > education12.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2010_11_PP.csv > education11.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2009_10_PP.csv > education10.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2008_09_PP.csv > education09.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2007_08_PP.csv > education08.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2006_07_PP.csv > education07.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2005_06_PP.csv > education06.csv

# %%
# !csvcut -c4,5,6,7,16,1739,37,38,60,61,429,430,431,432,1408,1413,1414,1415,1416,1504,1505,1506,1507,1508,1509,1665,1691,1696,1706,1639,1666,1697,1640 MERGED2004_05_PP.csv > education05.csv

# %%
# %load_ext sql
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# !echo 'redspot' | sudo -S service postgresql restart
# Out:
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.

# %%
# !createdb -U dbuser education

# %%
# %sql postgresql://dbuser@localhost:5432/education
# Out:
# 'Connected: dbuser@education'

# %% [markdown]
# ### Load csv to database and add corresponding year for every record

# %%
# !csvstat education15.csv
# Out:
#   1. INSTNM
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 7535
# 	5 most frequent values:
# 		UEI College:	8
# 		McCann School of Business & Technology:	7
# 		Stevens-Henager College:	7
# 		Columbia College:	5
# 		Bryan University:	5
# 	Max length: 93
#   2. CITY
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 2542
# 	5 most frequent values:
# 		New York:	89
# 		Chicago:	80
# 		Houston:	75
# 		Los Angeles:	57
# 		Miami:	53
# 	Max length: 24
#   3. STABBR
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 59
# 	5 most frequent values:
# 		CA:	795
# 		TX:	485
# 		NY:	467
# 		FL:	446
# 		PA:	405
# 	Max length: 2
#   4. ZIP
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 6513
# 	5 most frequent values:
# 		78229:	9
# 		90010:	9
# 		85021:	8
# 		46410:	7
# 		00961:	7
# 	Max length: 10
#   5. HIGHDEG
# 	<class 'int'>
# 	Nulls: False
# 	Values: 0, 1, 2, 3, 4
#   6. ICLEVEL
# 	<class 'int'>
# 	Nulls: False
# 	Values: 1, 2, 3
#   7. ADM_RATE
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 1519.6226999999992
# 	Mean: 0.6913661055505
# 	Median: 0.71295
# 	Standard Deviation: 0.20888087166216035
# 	Unique values: 1719
# 	5 most frequent values:
# 		1.0:	142
# 		0.6667:	15
# 		0.8889:	6
# 		0.75:	6
# 		0.5:	6
#   8. ADM_RATE_ALL
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 1660.7129671758555
# 	Mean: 0.6913875800066009
# 	Median: 0.718305827917755
# 	Standard Deviation: 0.20372609643152892
# 	Unique values: 1706
# 	5 most frequent values:
# 		1.0:	146
# 		0.85361152058056:	142
# 		0.77418668934722:	25
# 		0.62651766688141:	24
# 		0.7404536319265:	18
#   9. SAT_AVG
# 	<class 'int'>
# 	Nulls: True
# 	Min: 720
# 	Max: 1545
# 	Sum: 1381030
# 	Mean: 1059.0720858895706
# 	Median: 1039.5
# 	Standard Deviation: 133.30583529564603
# 	Unique values: 472
# 	5 most frequent values:
# 		1010:	26
# 		1050:	26
# 		1030:	20
# 		970:	20
# 		990:	19
#  10. SAT_AVG_ALL
# 	<class 'int'>
# 	Nulls: True
# 	Min: 720
# 	Max: 1545
# 	Sum: 1502135
# 	Mean: 1064.5889440113394
# 	Median: 1050
# 	Standard Deviation: 131.57394675190932
# 	Unique values: 467
# 	5 most frequent values:
# 		1050:	39
# 		1089:	30
# 		1010:	25
# 		1030:	24
# 		970:	20
#  11. RET_FT4
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 1621.3364999999976
# 	Mean: 0.7070808983863923
# 	Median: 0.7414
# 	Standard Deviation: 0.19560223518797457
# 	Unique values: 1505
# 	5 most frequent values:
# 		1.0:	92
# 		0.5:	57
# 		0.0:	48
# 		0.6667:	35
# 		0.75:	27
#  12. RET_FTL4
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 2636.8946000000055
# 	Mean: 0.6861552432995071
# 	Median: 0.6906
# 	Standard Deviation: 0.18009762742777305
# 	Unique values: 1712
# 	5 most frequent values:
# 		1.0:	215
# 		0.6667:	85
# 		0.75:	81
# 		0.8:	69
# 		0.5:	66
#  13. RET_PT4
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 643.3620000000001
# 	Mean: 0.4556388101983003
# 	Median: 0.45
# 	Standard Deviation: 0.2932212878519834
# 	Unique values: 389
# 	5 most frequent values:
# 		0.0:	184
# 		1.0:	155
# 		0.5:	150
# 		0.3333:	70
# 		0.6667:	45
#  14. RET_PTL4
# 	<class 'float'>
# 	Nulls: True
# 	Min: 0.0
# 	Max: 1.0
# 	Sum: 1246.8121999999948
# 	Mean: 0.5646794384057948
# 	Median: 0.50325
# 	Standard Deviation: 0.26348012864607384
# 	Unique values: 1009
# 	5 most frequent values:
# 		1.0:	244
# 		0.0:	75
# 		0.5:	71
# 		0.6667:	60
# 		0.75:	46
#  15. INC_PCT_LO
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 4536
# 	5 most frequent values:
# 		PrivacySuppressed:	476
# 		0.7181093571:	142
# 		0.7708312692:	85
# 		0.7320481758:	81
# 		0.7322646003:	38
# 	Max length: 17
#  16. INC_PCT_M1
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 3802
# 	5 most frequent values:
# 		PrivacySuppressed:	1217
# 		0.1437831467:	142
# 		0.0959080551:	85
# 		0.152076969:	81
# 		0.1411651797:	38
# 	Max length: 17
#  17. INC_PCT_M2
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 3470
# 	5 most frequent values:
# 		PrivacySuppressed:	1900
# 		0.0815370778:	142
# 		0.0624194987:	85
# 		0.0731064995:	81
# 		0.0773824334:	38
# 	Max length: 17
#  18. INC_PCT_H1
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2999
# 	5 most frequent values:
# 		PrivacySuppressed:	2659
# 		0.0383339019:	142
# 		0.0433964134:	85
# 		0.0283015555:	81
# 		0.0325880638:	38
# 	Max length: 17
#  19. INC_PCT_H2
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2995
# 	5 most frequent values:
# 		PrivacySuppressed:	2695
# 		0.0182365165:	142
# 		0.0274447637:	85
# 		0.0144668001:	81
# 		0.0165997227:	38
# 	Max length: 17
#  20. DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2096
# 	5 most frequent values:
# 		PrivacySuppressed:	990
# 		9500:	904
# 		5500:	224
# 		13566:	142
# 		12000:	135
# 	Max length: 17
#  21. GRAD_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2118
# 	5 most frequent values:
# 		PrivacySuppressed:	1408
# 		9500:	546
# 		27000:	319
# 		25827.5:	142
# 		25000:	125
# 	Max length: 17
#  22. WDRAW_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1572
# 	5 most frequent values:
# 		PrivacySuppressed:	1594
# 		4750:	910
# 		9500:	641
# 		5500:	362
# 		6334:	165
# 	Max length: 17
#  23. LO_INC_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2182
# 	5 most frequent values:
# 		PrivacySuppressed:	1534
# 		9500:	908
# 		12667:	154
# 		5500:	95
# 		6333:	92
# 	Max length: 17
#  24. MD_INC_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1650
# 	5 most frequent values:
# 		PrivacySuppressed:	2406
# 		9500:	442
# 		5500:	178
# 		17014:	142
# 		20000:	102
# 	Max length: 17
#  25. HI_INC_DEBT_MDN
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1421
# 	5 most frequent values:
# 		PrivacySuppressed:	2394
# 		5500:	486
# 		9500:	265
# 		12000:	223
# 		17000:	156
# 	Max length: 17
#  26. MN_EARN_WNE_P6
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  27. MN_EARN_WNE_P7
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  28. MN_EARN_WNE_P8
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  29. MN_EARN_WNE_P9
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  30. MN_EARN_WNE_P10
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  31. MD_EARN_WNE_P6
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  32. MD_EARN_WNE_P8
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  33. MD_EARN_WNE_P10
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#
# Row count: 7703

# %%
# %%sql
# DROP TABLE IF EXISTS education15;
# CREATE TABLE education15 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education15 FROM '/home/jovyan/work/education15.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 7703 rows affected.
# []

# %%
COALESCE(column, '')
# Out:
#   File "<ipython-input-25-352b24016162>", line 1
#     SELECT COALESCE(ADM_RATE, 0) FROM education15
#                   ^
# SyntaxError: invalid syntax

# %%
# %%sql
# ALTER TABLE education15
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2015
# Out:
# Done.
# []

# %%
# %%sql
# SELECT * FROM education15
# LIMIT 100
# Out:
# 100 rows affected.
# [('Alabama A & M University                                                                      ', 'Normal                   ', 'AL', '35762      ', 4, '1          ', '0.5256            ', '0.52560347439652  ', '827     ', '827     ', '0.6595            ', 'NULL              ', '0.3333            ', 'NULL              ', '0.6515211379      ', '0.167917819       ', '0.0975898854      ', '0.0513630976      ', '0.0316080601      ', '15000             ', '33888             ', '11500             ', '14413             ', '18255             ', '17250             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of Alabama at Birmingham                                                           ', 'Birmingham               ', 'AL', '35294-0110 ', 4, '1          ', '0.8569            ', '0.85691768826619  ', '1107    ', '1107    ', '0.8288            ', 'NULL              ', '0.575             ', 'NULL              ', '0.4627393838      ', '0.1623646961      ', '0.1388426311      ', '0.1286427977      ', '0.1074104913      ', '14382             ', '21941.5           ', '10000             ', '14725             ', '14692.5           ', '14000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Amridge University                                                                            ', 'Montgomery               ', 'AL', '36117-3553 ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0                 ', 'NULL              ', '0.6667            ', 'NULL              ', '0.7975830816      ', '0.1359516616      ', '0.0332326284      ', 'PrivacySuppressed ', 'PrivacySuppressed ', '9500              ', '23370             ', '8687.5            ', '8563              ', '15750             ', '13882             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of Alabama in Huntsville                                                           ', 'Huntsville               ', 'AL', '35899      ', 4, '1          ', '0.8203            ', '0.82034220532319  ', '1219    ', '1219    ', '0.7696            ', 'NULL              ', '0.6154            ', 'NULL              ', '0.4565544952      ', '0.1376192868      ', '0.1426418885      ', '0.138121547       ', '0.1250627825      ', '15750             ', '24097             ', '9500              ', '17107             ', '16938             ', '14000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Alabama State University                                                                      ', 'Montgomery               ', 'AL', '36104-0271 ', 4, '1          ', '0.5326            ', '0.53264694382901  ', '851     ', '851     ', '0.5725            ', 'NULL              ', '0.28              ', 'NULL              ', '0.6714959569      ', '0.1644204852      ', '0.0838948787      ', '0.0488544474      ', '0.0313342318      ', '14362             ', '33118.5           ', '11500             ', '14250             ', '15019             ', '14250             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('The University of Alabama                                                                     ', 'Tuscaloosa               ', 'AL', '35487-0166 ', 4, '1          ', '0.5105            ', '0.51046359971543  ', '1185    ', '1185    ', '0.867             ', 'NULL              ', '0.6               ', 'NULL              ', '0.2897661496      ', '0.1319749942      ', '0.1404260245      ', '0.1465617041      ', '0.2912711276      ', '17375             ', '23750             ', '10000             ', '18250             ', '17250             ', '16500             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Central Alabama Community College                                                             ', 'Alexander City           ', 'AL', '35010      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.4915            ', 'NULL              ', '0.5055            ', '0.663093415       ', '0.1615620214      ', '0.0995405819      ', '0.0574272588      ', '0.0183767228      ', '6506              ', '16127             ', '6113              ', '7174.5            ', '6239              ', '4500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Athens State University                                                                       ', 'Athens                   ', 'AL', '35611      ', 3, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', '0.5201793722      ', '0.1851377322      ', '0.1588725176      ', '0.0896860987      ', '0.0461242793      ', '12750             ', '18595             ', '8699              ', '12833             ', '13629             ', '12258             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Auburn University at Montgomery                                                               ', 'Montgomery               ', 'AL', '36117-3596 ', 4, '1          ', '0.8017            ', '0.80169571361281  ', '1009    ', '1009    ', '0.652             ', 'NULL              ', '0.3659            ', 'NULL              ', '0.5729800174      ', '0.1672458732      ', '0.1103388358      ', '0.0877497828      ', '0.0616854909      ', '9500              ', '21335             ', '6750              ', '9500              ', '10500             ', '10250             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Auburn University                                                                             ', 'Auburn                   ', 'AL', '36849      ', 4, '1          ', '0.8347            ', '0.83465031253685  ', '1215    ', '1215    ', '0.9052            ', 'NULL              ', '0.6               ', 'NULL              ', '0.2746940559      ', '0.1304632867      ', '0.1418269231      ', '0.1606206294      ', '0.2923951049      ', '17500             ', '21831             ', '8250              ', '16500             ', '18750             ', '17475             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Birmingham Southern College                                                                   ', 'Birmingham               ', 'AL', '35254      ', 3, '1          ', '0.5339            ', '0.53393501805054  ', '1181    ', '1181    ', '0.8371            ', 'NULL              ', 'NULL              ', 'NULL              ', '0.2311435523      ', '0.1143552311      ', '0.1824817518      ', '0.1946472019      ', '0.2773722628      ', '21500             ', '27000             ', '10500             ', '19750             ', '25717             ', '21500             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Chattahoochee Valley Community College                                                        ', 'Phenix City              ', 'AL', '36869      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5315            ', 'NULL              ', '0.2955            ', '0.6990769231      ', '0.1643076923      ', '0.0892307692      ', '0.0344615385      ', '0.0129230769      ', '5500              ', '9000              ', '5499.5            ', '5500              ', '5800              ', '5500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Concordia College Alabama                                                                     ', 'Selma                    ', 'AL', '36701      ', 3, '1          ', '0.5328            ', '0.53284671532846  ', '942     ', '942     ', '0.5238            ', 'NULL              ', '0.5               ', 'NULL              ', '0.8152985075      ', '0.1138059701      ', '0.0503731343      ', 'PrivacySuppressed ', 'PrivacySuppressed ', '9500              ', '32000             ', '9500              ', '9500              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('South University-Montgomery                                                                   ', 'Montgomery               ', 'AL', '36116      ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.5               ', 'NULL              ', '0.2857            ', 'NULL              ', '0.7032266573      ', '0.1410673466      ', '0.0858097415      ', '0.0443115878      ', '0.0255846668      ', '9500              ', '25167             ', '6334              ', '8171              ', '10559             ', '12387.5           ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Enterprise State Community College                                                            ', 'Enterprise               ', 'AL', '36330-1300 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5029            ', 'NULL              ', '0.3649            ', '0.6659482759      ', '0.1724137931      ', '0.0962643678      ', '0.0431034483      ', '0.0222701149      ', '5774              ', '8273              ', '5500              ', '6164              ', '5500              ', '5500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('James H Faulkner State Community College                                                      ', 'Bay Minette              ', 'AL', '36507-2698 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.603             ', 'NULL              ', '0.3524            ', '0.6401734104      ', '0.1404624277      ', '0.1101156069      ', '0.0760115607      ', '0.0332369942      ', '5500              ', '11000             ', '5500              ', '5500              ', '5500              ', '5500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Faulkner University                                                                           ', 'Montgomery               ', 'AL', '36109-3390 ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.6028            ', 'NULL              ', '0.3333            ', 'NULL              ', '0.6025778733      ', '0.1525241676      ', '0.1181525242      ', '0.0757250269      ', '0.0510204082      ', '15500             ', '22000             ', '12500             ', '16600             ', '14025             ', '13500             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Gadsden State Community College                                                               ', 'Gadsden                  ', 'AL', '35903      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5258            ', 'NULL              ', '0.4163            ', '0.7915289877      ', '0.1435866627      ', '0.0609792731      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('New Beginning College of Cosmetology                                                          ', 'Albertville              ', 'AL', '35951      ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.8205            ', 'NULL              ', 'NULL              ', '0.6842105263      ', '0.1447368421      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', '5500              ', '5500              ', '5972.5            ', '6153              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('George C Wallace State Community College-Dothan                                               ', 'Dothan                   ', 'AL', '36303-9234 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5631            ', 'NULL              ', '0.4608            ', '0.7910983489      ', '0.148241206       ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('George C Wallace State Community College-Hanceville                                           ', 'Hanceville               ', 'AL', '35077-2000 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6329            ', 'NULL              ', '0.4822            ', '0.585520623       ', '0.1655610037      ', '0.1370060571      ', '0.0813383329      ', '0.0305739833      ', '8000              ', '11186             ', '6865              ', '8000              ', '8000              ', '6750              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('George C Wallace State Community College-Selma                                                ', 'Selma                    ', 'AL', '36703-2808 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6092            ', 'NULL              ', '0.4054            ', '0.8716461204      ', '0.09862219        ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Herzing University-Birmingham                                                                 ', 'Birmingham               ', 'AL', '35209      ', 4, '1          ', '1                 ', '1                 ', 'NULL    ', 'NULL    ', '0                 ', 'NULL              ', 'NULL              ', 'NULL              ', '0.7406312803      ', '0.128502187       ', '0.0754226268      ', '0.0378295307      ', '0.0176143752      ', '10628             ', '23216.5           ', '7750              ', '9500              ', '14750             ', '14995             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Huntingdon College                                                                            ', 'Montgomery               ', 'AL', '36106-2148 ', 3, '1          ', '0.5839            ', '0.58385525400139  ', '1026    ', '1026    ', '0.705             ', 'NULL              ', 'NULL              ', 'NULL              ', '0.4020467836      ', '0.1754385965      ', '0.1432748538      ', '0.1257309942      ', '0.1535087719      ', '16701.5           ', '26230             ', '9014.5            ', '14764             ', '19120             ', '15764             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Heritage Christian University                                                                 ', 'Florence                 ', 'AL', '35630-9977 ', 4, '1          ', '1                 ', '1                 ', 'NULL    ', 'NULL    ', '0.5714            ', 'NULL              ', 'NULL              ', 'NULL              ', '0.6875            ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', '9875              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('J F Drake State Community and Technical College                                               ', 'Huntsville               ', 'AL', '35811      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.3873            ', 'NULL              ', '0.2535            ', '0.8603988604      ', '0.1082621083      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Jacksonville State University                                                                 ', 'Jacksonville             ', 'AL', '36265      ', 4, '1          ', '0.8326            ', '0.83260357022566  ', '1041    ', '1041    ', '0.718             ', 'NULL              ', '0.5625            ', 'NULL              ', '0.4515389653      ', '0.1833660773      ', '0.156843484       ', '0.1339227243      ', '0.0743287492      ', '15871             ', '23000             ', '11000             ', '17234             ', '16200             ', '14000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Jefferson Davis Community College                                                             ', 'Brewton                  ', 'AL', '36426      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5163            ', 'NULL              ', '0.3774            ', '0.7799717913      ', '0.167842031       ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Jefferson State Community College                                                             ', 'Birmingham               ', 'AL', '35215-3098 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5565            ', 'NULL              ', '0.4529            ', '0.6271571299      ', '0.1525885559      ', '0.1178474114      ', '0.0644868302      ', '0.0379200727      ', '4500              ', '8916.5            ', '3500              ', '3500              ', '4500              ', '5500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('John C Calhoun State Community College                                                        ', 'Tanner                   ', 'AL', '35671      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.582             ', 'NULL              ', '0.4474            ', '0.6252085264      ', '0.1519925857      ', '0.1151065802      ', '0.0658016682      ', '0.0418906395      ', '5500              ', '10500             ', '5500              ', '5500              ', '5500              ', '5500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Judson College                                                                                ', 'Marion                   ', 'AL', '36756      ', 3, '1          ', '0.6525            ', '0.65254237288135  ', 'NULL    ', 'NULL    ', '0.5606            ', 'NULL              ', '0                 ', 'NULL              ', '0.6584507042      ', '0.1126760563      ', '0.1373239437      ', 'PrivacySuppressed ', 'PrivacySuppressed ', '16797.5           ', '26000             ', '14000             ', '14250             ', '19000             ', '19500             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Lawson State Community College-Birmingham Campus                                              ', 'Birmingham               ', 'AL', '35221-1717 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.4991            ', 'NULL              ', '0.3509            ', '0.8332681018      ', '0.1295499022      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of West Alabama                                                                    ', 'Livingston               ', 'AL', '35470      ', 4, '1          ', '0.7199            ', '0.71992110453648  ', '990     ', '990     ', '0.6451            ', 'NULL              ', '0.6               ', 'NULL              ', '0.5989304813      ', '0.1399286988      ', '0.1051693405      ', '0.0909090909      ', '0.0650623886      ', '12500             ', '24253             ', '9500              ', '13182             ', '12000             ', '9699.5            ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Lurleen B Wallace Community College                                                           ', 'Andalusia                ', 'AL', '36420-1418 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6024            ', 'NULL              ', '0.4074            ', '0.75              ', '0.1745614035      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Marion Military Institute                                                                     ', 'Marion                   ', 'AL', '36756-3207 ', 2, '2          ', '0.6139            ', '0.61386138613861  ', '1055    ', '1055    ', 'NULL              ', '0.3534            ', 'NULL              ', 'NULL              ', '0.3596059113      ', '0.1477832512      ', '0.1625615764      ', '0.1502463054      ', '0.1798029557      ', '5500              ', '11500             ', '5500              ', '5500              ', '5500              ', '5500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Miles College                                                                                 ', 'Fairfield                ', 'AL', '35064-2621 ', 3, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.5236            ', 'NULL              ', '0                 ', 'NULL              ', '0.747553816       ', '0.1409001957      ', '0.0600130463      ', '0.0293542074      ', '0.0221787345      ', '12250             ', '36789.5           ', '9500              ', '11505             ', '14259.5           ', '14250             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of Mobile                                                                          ', 'Mobile                   ', 'AL', '36613-2842 ', 4, '1          ', '0.5847            ', '0.58473736372646  ', '1014    ', '1014    ', '0.7713            ', 'NULL              ', '0                 ', 'NULL              ', '0.4281842818      ', '0.1558265583      ', '0.1531165312      ', '0.1517615176      ', '0.1111111111      ', '21950             ', '27000             ', '20000             ', '25000             ', '20500             ', '19450             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of Montevallo                                                                      ', 'Montevallo               ', 'AL', '35115-6000 ', 4, '1          ', '0.743             ', '0.74299835255354  ', '1070    ', '1070    ', '0.7881            ', 'NULL              ', '0.4167            ', 'NULL              ', '0.4261715296      ', '0.142351901       ', '0.1635720601      ', '0.1485411141      ', '0.1193633952      ', '15110             ', '23266             ', '11000             ', '15000             ', '17000             ', '15000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Northwest-Shoals Community College                                                            ', 'Muscle Shoals            ', 'AL', '35661      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5853            ', 'NULL              ', '0.4196            ', '0.6658595642      ', '0.1638418079      ', '0.0968523002      ', '0.0544794189      ', '0.0189669088      ', '4750              ', '11250             ', '4500              ', '5000              ', '4500              ', '4250              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of North Alabama                                                                   ', 'Florence                 ', 'AL', '35632-0001 ', 4, '1          ', '0.6788            ', '0.67884267631103  ', '1029    ', '1029    ', '0.723             ', 'NULL              ', '0.2941            ', 'NULL              ', '0.4225654226      ', '0.1784641785      ', '0.1625911626      ', '0.1368511369      ', '0.0995280995      ', '12638             ', '21500             ', '8250              ', '12000             ', '13405             ', '13552             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Northeast Alabama Community College                                                           ', 'Rainsville               ', 'AL', '35986      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6097            ', 'NULL              ', '0.3571            ', '0.6706028589      ', '0.1622125544      ', '0.1180857676      ', '0.0379117464      ', '0.0111870727      ', '3500              ', '4500              ', '3023              ', '3500              ', '3475              ', '4650              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Oakwood University                                                                            ', 'Huntsville               ', 'AL', '35896      ', 4, '1          ', '0.4787            ', '0.47865275142315  ', '928     ', '928     ', '0.7637            ', 'NULL              ', '0                 ', 'NULL              ', '0.4231707317      ', '0.1963414634      ', '0.1487804878      ', '0.1256097561      ', '0.106097561       ', '23500             ', '27250             ', '21250             ', '22750             ', '24500             ', '24250             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Alabama Southern Community College                                                            ', 'Monroeville              ', 'AL', '36460      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5878            ', 'NULL              ', '0.4286            ', '0.8120868744      ', '0.1274787535      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Prince Institute-Southeast                                                                    ', 'Elmhurst                 ', 'IL', '60126      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.25              ', 'NULL              ', 'NULL              ', '0.5982142857      ', '0.1517857143      ', '0.1160714286      ', 'PrivacySuppressed ', 'PrivacySuppressed ', '15834             ', '20992             ', '14405             ', '13863             ', '18012             ', '16693             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Reid State Technical College                                                                  ', 'Evergreen                ', 'AL', '36401      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5735            ', 'NULL              ', '0.5556            ', '0.8475            ', '0.115             ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Bishop State Community College                                                                ', 'Mobile                   ', 'AL', '36603-5898 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.4084            ', 'NULL              ', '0.3231            ', '0.8894230769      ', '0.0846153846      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Samford University                                                                            ', 'Birmingham               ', 'AL', '35229-2240 ', 4, '1          ', '0.5954            ', '0.59536814507319  ', '1165    ', '1165    ', '0.8795            ', 'NULL              ', '0.8               ', 'NULL              ', '0.2541507024      ', '0.1060025543      ', '0.1558109834      ', '0.1519795658      ', '0.3320561941      ', '17250             ', '23000             ', '9500              ', '18750             ', '18123.5           ', '15674.5           ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Selma University                                                                              ', 'Selma                    ', 'AL', '36701      ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.3474            ', 'NULL              ', '0.1               ', 'NULL              ', '0.9209302326      ', '0.0511627907      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', '5050              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Shelton State Community College                                                               ', 'Tuscaloosa               ', 'AL', '35405-8522 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6032            ', 'NULL              ', '0.4071            ', '0.7839659454      ', '0.1599858106      ', '0.0525008868      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Snead State Community College                                                                 ', 'Boaz                     ', 'AL', '35957-0734 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6235            ', 'NULL              ', '0.45              ', '0.6472889883      ', '0.1676914477      ', '0.1173840134      ', '0.0519843488      ', '0.0156512018      ', '3500              ', '6374              ', '3500              ', '3500              ', '3500              ', '3955              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of South Alabama                                                                   ', 'Mobile                   ', 'AL', '36688-0002 ', 4, '1          ', '0.8335            ', '0.8334858188472   ', '1048    ', '1048    ', '0.7107            ', 'NULL              ', '0.3953            ', 'NULL              ', '0.4681522382      ', '0.1609150069      ', '0.1435614277      ', '0.1212778545      ', '0.1060934727      ', '13000             ', '24711             ', '9294              ', '13000             ', '14000             ', '12500             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Spring Hill College                                                                           ', 'Mobile                   ', 'AL', '36608-1791 ', 4, '1          ', '0.5177            ', '0.51769415532425  ', '1116    ', '1116    ', '0.7262            ', 'NULL              ', '0.3333            ', 'NULL              ', '0.3278195489      ', '0.1503759398      ', '0.1518796992      ', '0.1578947368      ', '0.2120300752      ', '20500             ', '27000             ', '15738             ', '21750             ', '20500             ', '20000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Southeastern Bible College                                                                    ', 'Birmingham               ', 'AL', '35244-2083 ', 3, '1          ', '1                 ', '1                 ', '930     ', '930     ', '0.8182            ', 'NULL              ', 'NULL              ', 'NULL              ', '0.5321100917      ', '0.2293577982      ', 'PrivacySuppressed ', '0.1009174312      ', 'PrivacySuppressed ', '20000             ', '24000             ', '14000             ', '19582             ', '20275             ', '19000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Stillman College                                                                              ', 'Tuscaloosa               ', 'AL', '35401      ', 3, '1          ', '0.5901            ', '0.59009532666821  ', '811     ', '811     ', '0.6687            ', 'NULL              ', 'NULL              ', 'NULL              ', '0.6902356902      ', '0.1296296296      ', '0.0841750842      ', '0.069023569       ', '0.0269360269      ', '15575             ', '38218             ', '9500              ', '16200             ', '17500             ', '9500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Talladega College                                                                             ', 'Talladega                ', 'AL', '35160      ', 3, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.4492            ', 'NULL              ', '0.75              ', 'NULL              ', '0.73              ', '0.1585714286      ', '0.0742857143      ', 'PrivacySuppressed ', 'PrivacySuppressed ', '15625             ', '27745             ', '9500              ', '14250             ', '19521             ', '23125             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('H Councill Trenholm State Community College                                                   ', 'Montgomery               ', 'AL', '36108-3199 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5522            ', 'NULL              ', '0.3623            ', '0.8206650831      ', '0.1448931116      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Troy University                                                                               ', 'Troy                     ', 'AL', '36082-0001 ', 4, '1          ', '0.4414            ', '0.4414457070707   ', '1050    ', '1050    ', '0.7514            ', 'NULL              ', '0.376             ', 'NULL              ', '0.5715957291      ', '0.1670323241      ', '0.1192043294      ', '0.0854175808      ', '0.0567500366      ', '14500             ', '25000             ', '11016.5           ', '14250             ', '15558             ', '13824             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Tuskegee University                                                                           ', 'Tuskegee                 ', 'AL', '36088-1920 ', 4, '1          ', '0.4922            ', '0.49219800914716  ', '978     ', '978     ', '0.7178            ', 'NULL              ', '1                 ', 'NULL              ', '0.4792            ', '0.1792            ', '0.1344            ', '0.1048            ', '0.1024            ', '21500             ', '33500             ', '14700             ', '21000             ', '23500             ', '19625             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('United States Sports Academy                                                                  ', 'Daphne                   ', 'AL', '36526-7055 ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', '0.62              ', '0.14              ', '0.11              ', 'PrivacySuppressed ', 'PrivacySuppressed ', '10225             ', '25503.5           ', '6656              ', '9950              ', '11323.5           ', '9157              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Bevill State Community College                                                                ', 'Jasper                   ', 'AL', '35501      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6109            ', 'NULL              ', '0.4408            ', '0.7863247863      ', '0.1497975709      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of Alaska Anchorage                                                                ', 'Anchorage                ', 'AK', '99508      ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.7164            ', 'NULL              ', '0.4549            ', 'NULL              ', '0.5048461863      ', '0.1744627054      ', '0.1352718078      ', '0.0941845765      ', '0.091234724       ', '10261             ', '19449.5           ', '9250              ', '11000             ', '10500             ', '8250              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Alaska Bible College                                                                          ', 'Palmer                   ', 'AK', '99645      ', 3, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.3333            ', 'NULL              ', 'NULL              ', 'NULL              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of Alaska Fairbanks                                                                ', 'Fairbanks                ', 'AK', '99775-7500 ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.7756            ', 'NULL              ', '0.4857            ', 'NULL              ', '0.4835322196      ', '0.1832935561      ', '0.1360381862      ', '0.0968973747      ', '0.1002386635      ', '10283             ', '19355             ', '8598.5            ', '11000             ', '11000             ', '8312.5            ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of Alaska Southeast                                                                ', 'Juneau                   ', 'AK', '99801-8697 ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.7167            ', 'NULL              ', '0.6364            ', 'NULL              ', '0.5174216028      ', '0.2090592334      ', '0.1271777003      ', '0.0888501742      ', '0.0574912892      ', '9804              ', '16875             ', '8822              ', '11251             ', '10500             ', '7550              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
# ...
#  ('Arizona Academy of Beauty-East                                                                ', 'Tucson                   ', 'AZ', '85712      ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6667            ', 'NULL              ', 'NULL              ', '0.7627118644      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', '5500              ', '5500              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Arizona Automotive Institute                                                                  ', 'Glendale                 ', 'AZ', '85301-3579 ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6688            ', 'NULL              ', 'NULL              ', '0.7739130435      ', '0.1343873518      ', '0.0632411067      ', 'PrivacySuppressed ', 'PrivacySuppressed ', '9500              ', '13000             ', '9500              ', '9500              ', '9500              ', '9500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Brookline College-Phoenix                                                                     ', 'Phoenix                  ', 'AZ', '85021      ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.4228            ', 'NULL              ', 'NULL              ', 'NULL              ', '0.8083402375      ', '0.1049433858      ', '0.0533001933      ', '0.021264844       ', '0.0121513394      ', '9500              ', '9500              ', '5022              ', '9500              ', '9500              ', '9500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Arizona State University-Tempe                                                                ', 'Tempe                    ', 'AZ', '85287      ', 4, '1          ', '0.8433            ', '0.78443051201671  ', '1145    ', '1135    ', '0.8609            ', 'NULL              ', '0.4286            ', 'NULL              ', '0.4322822521      ', '0.1674700408      ', '0.1459797818      ', '0.1113007967      ', '0.1429671286      ', '15034.5           ', '20229             ', '9500              ', '15651             ', '15522.5           ', '14590             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Arizona Western College                                                                       ', 'Yuma                     ', 'AZ', '85365-8834 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6043            ', 'NULL              ', '0.4055            ', '0.6851248643      ', '0.1887079262      ', '0.1055374593      ', '0.0156351792      ', '0.0049945711      ', '4250              ', '5500              ', '4000              ', '4750              ', '3500              ', '2750              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('University of Arizona                                                                         ', 'Tucson                   ', 'AZ', '85721-0066 ', 4, '1          ', '0.7462            ', '0.74617241695443  ', 'NULL    ', 'NULL    ', '0.8189            ', 'NULL              ', '0.6273            ', 'NULL              ', '0.3870106762      ', '0.1600533808      ', '0.1408362989      ', '0.1161921708      ', '0.1959074733      ', '13279             ', '19000             ', '8500              ', '13500             ', '13654             ', '13000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Southwest University of Visual Arts-Tucson                                                    ', 'Tucson                   ', 'AZ', '85716      ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0.7692            ', 'NULL              ', '0.6667            ', 'NULL              ', '0.6212121212      ', '0.2045454545      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', '35500             ', '49750             ', '20125             ', '40000             ', '34500             ', '32537             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Central Arizona College                                                                       ', 'Coolidge                 ', 'AZ', '85128-9030 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.4779            ', 'NULL              ', '0.3278            ', '0.6388020833      ', '0.1973958333      ', '0.1135416667      ', '0.03671875        ', '0.0135416667      ', '5500              ', '9993              ', '5014.5            ', '4956.5            ', '5882              ', '5500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Brown Mackie College-Tucson                                                                   ', 'Tucson                   ', 'AZ', '85712      ', 3, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '1                 ', 'NULL              ', 'NULL              ', 'NULL              ', '0.7764638347      ', '0.1136624569      ', '0.060199005       ', '0.0311519326      ', '0.0185227708      ', '12004.5           ', '22141.5           ', '6625.5            ', '11093.5           ', '14326             ', '13000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Charles of Italy Beauty College                                                               ', 'Lake Havasu City         ', 'AZ', '86403      ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.9529            ', 'NULL              ', 'NULL              ', '0.7551020408      ', '0.1326530612      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', '6500              ', '7389              ', '4125              ', '5948              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Cochise County Community College District                                                     ', 'Douglas                  ', 'AZ', '85607-6190 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5607            ', 'NULL              ', '0.3592            ', '0.7109252483      ', '0.1662310507      ', '0.0878201777      ', '0.020386827       ', '0.0146366963      ', '3952              ', '6500              ', '3634.5            ', '3839.5            ', '4289              ', '4000              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Empire Beauty School-Flagstaff                                                                ', 'Flagstaff                ', 'AZ', '86004      ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.7241            ', 'NULL              ', 'NULL              ', '0.7538133008      ', '0.1076876144      ', '0.072300183       ', '0.0405735204      ', '0.0256253813      ', '7775              ', '10050             ', '4749.5            ', '7350              ', '8028              ', '8080              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Empire Beauty School-Chandler                                                                 ', 'Chandler                 ', 'AZ', '85224      ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6667            ', 'NULL              ', '0.8               ', '0.7538133008      ', '0.1076876144      ', '0.072300183       ', '0.0405735204      ', '0.0256253813      ', '7775              ', '10050             ', '4749.5            ', '7350              ', '8028              ', '8080              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Cortiva Institute-Tucson                                                                      ', 'Tucson                   ', 'AZ', '85710      ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.7561            ', 'NULL              ', '0.8077            ', '0.748502994       ', '0.1137724551      ', '0.0838323353      ', '0.0299401198      ', '0.0239520958      ', '6333              ', '6333              ', '3167              ', '6333              ', '6333              ', '6333              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Avalon School of Cosmetology-Mesa                                                             ', 'Mesa                     ', 'AZ', '85210      ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.7013            ', 'NULL              ', '0.8193            ', '0.6321642429      ', '0.1497005988      ', '0.1060735672      ', '0.0650128315      ', '0.0470487596      ', '9555              ', '11458             ', '4540.5            ', '8615              ', '10555             ', '10552             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Eastern Arizona College                                                                       ', 'Thatcher                 ', 'AZ', '85552-0769 ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.5602            ', 'NULL              ', '0.4408            ', '0.717630854       ', '0.1831955923      ', '0.08815427        ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Embry-Riddle Aeronautical University-Prescott                                                 ', 'Prescott                 ', 'AZ', '86301-3720 ', 4, '1          ', '0.8016            ', '0.74323927101704  ', 'NULL    ', 'NULL    ', '0.8217            ', 'NULL              ', '0.6               ', 'NULL              ', '0.4274699659      ', '0.1897077282      ', '0.1538461538      ', '0.1052537206      ', '0.1237224314      ', '13000             ', '24411             ', '9497.5            ', '12473             ', '12478             ', '15500             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Frank Lloyd Wright School of Architecture                                                     ', 'Scottsdale               ', 'AZ', '85261-4430 ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Glendale Community College                                                                    ', 'Glendale                 ', 'AZ', '85302      ', 2, '2          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.597             ', 'NULL              ', '0.3728            ', '0.7026007139      ', '0.1642019378      ', '0.0924018358      ', '0.0319224885      ', '0.008873024       ', '3500              ', '7000              ', '3500              ', '3500              ', '4454              ', '3500              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('Grand Canyon University                                                                       ', 'Phoenix                  ', 'AZ', '85017      ', 4, '1          ', '0.5757            ', '0.57566629011338  ', 'NULL    ', 'NULL    ', '0.6236            ', 'NULL              ', '0.3058            ', 'NULL              ', '0.545763455       ', '0.1456757646      ', '0.1320289378      ', '0.1022141839      ', '0.0743176587      ', '11806             ', '18750             ', '6785.5            ', '9500              ', '14102.5           ', '15625             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              '),
#  ('International Academy of Hair Design                                                          ', 'Tempe                    ', 'AZ', '85282-6730 ', 1, '3          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', 'NULL              ', '0.6269            ', 'NULL              ', 'NULL              ', '0.78125           ', '0.1284722222      ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'PrivacySuppressed ', '7000              ', '10556             ', '4750              ', '6333              ', 'PrivacySuppressed ', 'PrivacySuppressed ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ')]

# %%
# %%sql
# =SUBSTITUTE(A2,"Author","Authoring")

# %%
# %%sql
# DROP TABLE IF EXISTS education14;
# CREATE TABLE education14 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education14 FROM '/home/jovyan/work/education14.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 7804 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education14
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2014
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education13;
# CREATE TABLE education13 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education13 FROM '/home/jovyan/work/education13.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 7793 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education13
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2013
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education12;
# CREATE TABLE education12 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education12 FROM '/home/jovyan/work/education12.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 7675 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education12
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2012
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education11;
# CREATE TABLE education11 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education11 FROM '/home/jovyan/work/education11.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 7414 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education11
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2011
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education10;
# CREATE TABLE education10 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education10 FROM '/home/jovyan/work/education10.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 7149 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education10
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2010
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education09;
# CREATE TABLE education09 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education09 FROM '/home/jovyan/work/education09.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 6975 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education09
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2009
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education08;
# CREATE TABLE education08 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education08 FROM '/home/jovyan/work/education08.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 6890 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education08
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2008
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education07;
# CREATE TABLE education07 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education07 FROM '/home/jovyan/work/education07.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 6848 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education07
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2007
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education06;
# CREATE TABLE education06 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education06 FROM '/home/jovyan/work/education06.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 6824 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education06
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2006
# Out:
# Done.
# []

# %%
# %%sql
# DROP TABLE IF EXISTS education05;
# CREATE TABLE education05 (
#     INSTITUTION CHAR(94),
#     CITY CHAR(25),
#     STABBR CHAR(2),
#     ZIP CHAR(11),
#     HIGHDEG INT,
#     ICLEVEL CHAR(11),
#     ADM_RATE CHAR(18),
#     ADM_RATE_ALL CHAR(18),
#     SAT_AVG CHAR(8),
#     SAT_AVG_ALL CHAR(8),
#     RET_FT4 CHAR(18),
#     RET_FTL4 CHAR(18),
#     RET_PT4 CHAR(18),
#     RET_PTL4 CHAR(18),
#     INC_PCT_LO CHAR(18),
#     INC_PCT_M1 CHAR(18),
#     INC_PCT_M2 CHAR(18),
#     INC_PCT_H1 CHAR(18),
#     INC_PCT_H2 CHAR(18),
#     DEBT_MDN CHAR(18),
#     GRAD_DEBT_MDN CHAR(18),
#     WDRAW_DEBT_MDN CHAR(18),
#     LO_INC_DEBT_MDN CHAR(18),
#     MD_INC_DEBT_MDN CHAR(18),
#     HI_INC_DEBT_MDN CHAR(18),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY education05 FROM '/home/jovyan/work/education05.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 6660 rows affected.
# []

# %%
# %%sql
# ALTER TABLE education05
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2005
# Out:
# Done.
# []

# %% [markdown]
# ### Merge all datasets into one and put it into database

# %%
# %%sql
# DROP TABLE IF EXISTS education;
# SELECT *
# INTO education
# FROM (
#     SELECT * FROM education15
#     UNION ALL
#     SELECT * FROM education14
#     UNION ALL
#     SELECT * FROM education13
#     UNION ALL
#     SELECT * FROM education12
#     UNION ALL
#     SELECT * FROM education11
#     UNION ALL
#     SELECT * FROM education10
#     UNION ALL
#     SELECT * FROM education09
#     UNION ALL
#     SELECT * FROM education08
#     UNION ALL
#     SELECT * FROM education07
#     UNION ALL
#     SELECT * FROM education06
#     UNION ALL
#     SELECT * FROM education05
#     ) AS educational
# Out:
# Done.
# 79735 rows affected.
# []

# %%
# %%sql
# SELECT count(*) FROM education
# Out:
# 1 rows affected.
# [(79735,)]

# %%
# %%sql
# SELECT * FROM education
# ORDER BY year DESC
# LIMIT 5
# Out:
# 5 rows affected.
# [('University of Alabama at Birmingham                                                           ', 'Birmingham               ', 'AL', '35294-0110 ', 4, '1          ', '0.8569            ', '0.85691768826619  ', '1107    ', '1107    ', '0.8288            ', 'NULL              ', '0.575             ', 'NULL              ', '0.4627393838      ', '0.1623646961      ', '0.1388426311      ', '0.1286427977      ', '0.1074104913      ', '14382             ', '21941.5           ', '10000             ', '14725             ', '14692.5           ', '14000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 2015),
#  ('Amridge University                                                                            ', 'Montgomery               ', 'AL', '36117-3553 ', 4, '1          ', 'NULL              ', 'NULL              ', 'NULL    ', 'NULL    ', '0                 ', 'NULL              ', '0.6667            ', 'NULL              ', '0.7975830816      ', '0.1359516616      ', '0.0332326284      ', 'PrivacySuppressed ', 'PrivacySuppressed ', '9500              ', '23370             ', '8687.5            ', '8563              ', '15750             ', '13882             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 2015),
#  ('University of Alabama in Huntsville                                                           ', 'Huntsville               ', 'AL', '35899      ', 4, '1          ', '0.8203            ', '0.82034220532319  ', '1219    ', '1219    ', '0.7696            ', 'NULL              ', '0.6154            ', 'NULL              ', '0.4565544952      ', '0.1376192868      ', '0.1426418885      ', '0.138121547       ', '0.1250627825      ', '15750             ', '24097             ', '9500              ', '17107             ', '16938             ', '14000             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 2015),
#  ('Alabama State University                                                                      ', 'Montgomery               ', 'AL', '36104-0271 ', 4, '1          ', '0.5326            ', '0.53264694382901  ', '851     ', '851     ', '0.5725            ', 'NULL              ', '0.28              ', 'NULL              ', '0.6714959569      ', '0.1644204852      ', '0.0838948787      ', '0.0488544474      ', '0.0313342318      ', '14362             ', '33118.5           ', '11500             ', '14250             ', '15019             ', '14250             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 2015),
#  ('Alabama A & M University                                                                      ', 'Normal                   ', 'AL', '35762      ', 4, '1          ', '0.5256            ', '0.52560347439652  ', '827     ', '827     ', '0.6595            ', 'NULL              ', '0.3333            ', 'NULL              ', '0.6515211379      ', '0.167917819       ', '0.0975898854      ', '0.0513630976      ', '0.0316080601      ', '15000             ', '33888             ', '11500             ', '14413             ', '18255             ', '17250             ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 'NULL              ', 2015)]

# %% [markdown]
# ### Another dataset about earnings for 2015

# %%
# !wget https://ed-public-download.apps.cloud.gov/downloads/Most-Recent-Cohorts-Treasury-Elements.csv
# Out:
# --2016-12-02 22:33:07--  https://ed-public-download.apps.cloud.gov/downloads/Most-Recent-Cohorts-Treasury-Elements.csv
# Resolving ed-public-download.apps.cloud.gov (ed-public-download.apps.cloud.gov)... 52.73.98.33, 107.23.95.12, 2406:da00:ff00::6b17:5f0c, ...
# Connecting to ed-public-download.apps.cloud.gov (ed-public-download.apps.cloud.gov)|52.73.98.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5886017 (5.6M) [text/csv]
# Saving to: ‘Most-Recent-Cohorts-Treasury-Elements.csv.1’
#
# Most-Recent-Cohorts 100%[=====================>]   5.61M  13.6MB/s   in 0.4s
#
# 2016-12-02 22:33:08 (13.6 MB/s) - ‘Most-Recent-Cohorts-Treasury-Elements.csv.1’ saved [5886017/5886017]

# %%
# !csvcut -n Most-Recent-Cohorts-Treasury-Elements.csv
# Out:
#   1: ﻿UNITID
#   2: OPEID
#   3: OPEID6
#   4: INSTNM
#   5: COUNT_ED
#   6: AGEGE24
#   7: PCT_WHITE
#   8: PCT_BLACK
#   9: PCT_ASIAN
#  10: PCT_HISPANIC
#  11: PCT_BA
#  12: PCT_GRAD_PROF
#  13: PCT_BORN_US
#  14: MEDIAN_HH_INC
#  15: POVERTY_RATE
#  16: UNEMP_RATE
#  17: LN_MEDIAN_HH_INC
#  18: COUNT_NWNE_P10
#  19: COUNT_WNE_P10
#  20: MN_EARN_WNE_P10
#  21: MD_EARN_WNE_P10
#  22: PCT10_EARN_WNE_P10
#  23: PCT25_EARN_WNE_P10
#  24: PCT75_EARN_WNE_P10
#  25: PCT90_EARN_WNE_P10
#  26: SD_EARN_WNE_P10
#  27: COUNT_WNE_INC1_P10
#  28: COUNT_WNE_INC2_P10
#  29: COUNT_WNE_INC3_P10
#  30: COUNT_WNE_INDEP0_INC1_P10
#  31: COUNT_WNE_INDEP0_P10
#  32: COUNT_WNE_INDEP1_P10
#  33: COUNT_WNE_MALE0_P10
#  34: COUNT_WNE_MALE1_P10
#  35: GT_25K_P10
#  36: MN_EARN_WNE_INC1_P10
#  37: MN_EARN_WNE_INC2_P10
#  38: MN_EARN_WNE_INC3_P10
#  39: MN_EARN_WNE_INDEP0_INC1_P10
#  40: MN_EARN_WNE_INDEP0_P10
#  41: MN_EARN_WNE_INDEP1_P10
#  42: MN_EARN_WNE_MALE0_P10
#  43: MN_EARN_WNE_MALE1_P10
#  44: COUNT_NWNE_P6
#  45: COUNT_WNE_P6
#  46: MN_EARN_WNE_P6
#  47: MD_EARN_WNE_P6
#  48: PCT10_EARN_WNE_P6
#  49: PCT25_EARN_WNE_P6
#  50: PCT75_EARN_WNE_P6
#  51: PCT90_EARN_WNE_P6
#  52: SD_EARN_WNE_P6
#  53: COUNT_WNE_INC1_P6
#  54: COUNT_WNE_INC2_P6
#  55: COUNT_WNE_INC3_P6
#  56: COUNT_WNE_INDEP0_INC1_P6
#  57: COUNT_WNE_INDEP0_P6
#  58: COUNT_WNE_INDEP1_P6
#  59: COUNT_WNE_MALE0_P6
#  60: COUNT_WNE_MALE1_P6
#  61: GT_25K_P6
#  62: MN_EARN_WNE_INC1_P6
#  63: MN_EARN_WNE_INC2_P6
#  64: MN_EARN_WNE_INC3_P6
#  65: MN_EARN_WNE_INDEP0_INC1_P6
#  66: MN_EARN_WNE_INDEP0_P6
#  67: MN_EARN_WNE_INDEP1_P6
#  68: MN_EARN_WNE_MALE0_P6
#  69: MN_EARN_WNE_MALE1_P6
#  70: COUNT_NWNE_P7
#  71: COUNT_WNE_P7
#  72: MN_EARN_WNE_P7
#  73: SD_EARN_WNE_P7
#  74: GT_25K_P7
#  75: COUNT_NWNE_P8
#  76: COUNT_WNE_P8
#  77: MN_EARN_WNE_P8
#  78: MD_EARN_WNE_P8
#  79: PCT10_EARN_WNE_P8
#  80: PCT25_EARN_WNE_P8
#  81: PCT75_EARN_WNE_P8
#  82: PCT90_EARN_WNE_P8
#  83: SD_EARN_WNE_P8
#  84: GT_25K_P8
#  85: COUNT_NWNE_P9
#  86: COUNT_WNE_P9
#  87: MN_EARN_WNE_P9
#  88: SD_EARN_WNE_P9
#  89: GT_25K_P9

# %%
# !csvcut -c4,46,72,77,87,20,47,78,21 Most-Recent-Cohorts-Treasury-Elements.csv > recentearnings.csv

# %%
# %%sql
# DROP TABLE IF EXISTS recentearnings;
# CREATE TABLE recentearnings (
#     INSTITUTION CHAR(94),
#     MN_EARN_WNE_P6 CHAR(18),
#     MN_EARN_WNE_P7 CHAR(18),
#     MN_EARN_WNE_P8 CHAR(18),
#     MN_EARN_WNE_P9 CHAR(18),
#     MN_EARN_WNE_P10 CHAR(18),
#     MD_EARN_WNE_P6 CHAR(18),
#     MD_EARN_WNE_P8 CHAR(18),
#     MD_EARN_WNE_P10 CHAR(18)
#     )
# Out:
# Done.
# Done.
# []

# %%
# %%sql
# COPY recentearnings FROM '/home/jovyan/work/recentearnings.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 7703 rows affected.
# []

# %%
# %%sql
# ALTER TABLE recentearnings
# ADD year INT NOT NULL
# CONSTRAINT year DEFAULT 2015
# Out:
# Done.
# []

# %%
# %%sql
# SELECT * FROM recentearnings
# LIMIT 5
# Out:
# 5 rows affected.
# [('Alabama A & M University                                                                      ', '25600             ', '29600             ', '30000             ', '33800             ', '35000             ', '22000             ', '26600             ', '30300             ', 2015),
#  ('University of Alabama at Birmingham                                                           ', '37500             ', '40000             ', '42000             ', '44500             ', '46300             ', '33300             ', '36900             ', '39700             ', 2015),
#  ('Amridge University                                                                            ', '40100             ', '38700             ', '39100             ', '42400             ', '44800             ', '35200             ', '36400             ', '40100             ', 2015),
#  ('University of Alabama in Huntsville                                                           ', '39300             ', '43400             ', '44900             ', '50200             ', '50400             ', '35900             ', '40900             ', '45500             ', 2015),
#  ('Alabama State University                                                                      ', '22200             ', '25200             ', '25700             ', '29400             ', '29400             ', '20300             ', '23000             ', '26600             ', 2015)]
